# %%
#!/usr/bin/env python
"""
STAGE 03 · RATIO FABRICATION   v3.0 – 2025-06-20
─────────────────────────────────────────────────
• Reads Stage-02 wide file and fabricates every ratio defined in
  *ratio_library.py* (~400 base + optional Log_/Sqrt_ variants).

• Creates two copies per ratio
      <Ratio>_raw      – un-winsorised, unclipped
      <Ratio>          – 1 % / 99 % two-sided winsorised

Output
------
<OUTPUT_ROOT>/event=<SWAN_YEAR>/<RUN_TAG>/stage03/
    └─ Stage3_Data_WithRatios_<SWAN_YEAR>.(csv|parquet)
"""
from __future__ import annotations
import io, logging, os, warnings
from pathlib import Path
from typing import Callable, Dict, List, Literal

import numpy as np
import pandas as pd

from pipeline_utils import load_cfg, resolve_run_dir, ensure_three_letter_tickers
from ratio_library   import (
    ratio_funcs, derived_ratio_funcs, _ensure_core_columns, winsor
)

# ─── 1 · CONFIG ─────────────────────────────────────────────────
CFG          = load_cfg()
EVENTS       = {str(k): v for k, v in CFG.get("events", {}).items()}
C3           = CFG.get("stage3", {})
DEF          = CFG["defaults"]

SWAN_YEAR    = str(os.getenv("SWAN_YEAR") or next(iter(EVENTS)))
SAVE_FMT: Literal["csv", "parquet"] = os.getenv(
    "SAVE_FORMAT", DEF.get("SAVE_FORMAT", "csv")
).lower()
INCLUDE_TR   = bool(DEF.get("include_transforms", True))

RUN_DIR = resolve_run_dir(
    swan_year = SWAN_YEAR,
    run_tag   = os.getenv("RUN_TAG"),
    must_have = f"stage02/Stage2_Data_WithMetrics_{SWAN_YEAR}.{SAVE_FMT}",
)
STAGE2_F = RUN_DIR / "stage02" / f"Stage2_Data_WithMetrics_{SWAN_YEAR}.{SAVE_FMT}"

OUT_DIR  = RUN_DIR / "stage03"; OUT_DIR.mkdir(parents=True, exist_ok=True)
OUT_F    = OUT_DIR / f"Stage3_Data_WithRatios_{SWAN_YEAR}.{SAVE_FMT}"

DATE_COL = C3.get("date_col", "ReportDate")
ID_COL   = C3.get("id_col",   "Symbol")
WINSOR_PCT = float(C3.get("winsor_pct", 0.01))

# ─── 2 · LOGGER ─────────────────────────────────────────────────
logging.basicConfig(
    level   = logging.INFO,
    format  = "%(asctime)s | %(levelname)-7s | %(message)s",
    handlers=[logging.FileHandler(OUT_DIR / "stage03.log", "w", "utf-8"),
              logging.StreamHandler()],
)
log = logging.getLogger(__name__)
log.info("==========  STAGE 03  (SWAN %s) ==========", SWAN_YEAR)
log.info("Load file  : %s", STAGE2_F.name)
log.info("Save file  : %s", OUT_F.name)
log.info("Include transforms: %s", INCLUDE_TR)

warnings.filterwarnings("ignore", category=RuntimeWarning)

# ══════════ 3 · LOAD + CORE COLS ═══════════════════════════════
if SAVE_FMT == "parquet":
    df = pd.read_parquet(STAGE2_F)
else:
    df = pd.read_csv(STAGE2_F, parse_dates=[DATE_COL], low_memory=False)

df = ensure_three_letter_tickers(df, ID_COL)
df.sort_values([ID_COL, DATE_COL], inplace=True)
df = _ensure_core_columns(df)               # adds NetAssets etc.

log.info("Rows loaded: %s", f"{len(df):,}")

# ══════════ 4 · RATIO FUNCTION ROSTER ══════════════════════════
all_funcs: Dict[str, Callable] = dict(ratio_funcs)          # base ≈400
if INCLUDE_TR:
    all_funcs.update(derived_ratio_funcs or {})             # Log_/Sqrt_
else:
    # strip Log_/Sqrt_ if user disabled transforms
    for n in list(derived_ratio_funcs):
        all_funcs.pop(n, None)

ratio_names: List[str] = sorted(all_funcs)
log.info("Total candidate ratios: %d", len(ratio_names))

# ══════════ 5 · MAIN LOOP ═════════════════════════════════════
for name in ratio_names:
    fn = all_funcs[name]
    try:
        res = fn(df)                     # pass entire DF
    except Exception as exc:
        log.warning("❌ %-40s failed (%s)", name, exc)
        continue

    # normalise to Series
    if isinstance(res, (pd.Series, pd.DataFrame, np.ndarray, int, float)):
        series = (
            res if isinstance(res, pd.Series)
            else pd.Series(res, index=df.index, name=name)
        ).astype("float64")
        df[f"{name}_raw"] = series
        df[name]          = winsor(series, WINSOR_PCT)
    else:
        log.warning("⚠️  %-40s returned unsupported %s – skipped",
                    name, type(res))

log.info("Ratios computed: raw=%d | winsor=%d",
         df.filter(like="_raw").shape[1],
         len([c for c in df.columns if c in ratio_names]))

# ══════════ 6 · SAVE & LOG ═════════════════════════════════════
if SAVE_FMT == "parquet":
    df.to_parquet(OUT_F, index=False)
else:
    df.to_csv(OUT_F, index=False)

buf = io.StringIO(); df.info(buf=buf)
log.info("Final DataFrame info:\n%s", buf.getvalue())
log.info("Saved → %s", OUT_F.name)

# cache for downstream notebooks
data_stage_3 = df.copy()
log.info("✅  STAGE 03 complete")
# Out:
# 2025-06-14 12:47:52,510 | INFO    | ==========  STAGE 03: EXTENDED RATIO FACTORY  ==========
# 2025-06-14 12:47:52,511 | INFO    | RUN_DIR        : C:\Users\Jason Pohl\OneDrive - Bond University\PhD\rff\outputs_rff\event=2000\2025-06-13
# 2025-06-14 12:47:52,512 | INFO    | SWAN_YEAR=2000  RUN_DATE=2025-06-13  WINSOR_PCT=0.01
# 2025-06-14 12:47:52,512 | INFO    | DATE_COL / ID_COL = ReportDate / Symbol
# 2025-06-14 12:47:53,556 | INFO    | Stage-02 CSV loaded: 34862 rows
# 2025-06-14 12:47:54,222 | INFO    |    (base) computed  25 / 219 ratios
# 2025-06-14 12:47:59,161 | INFO    |    (base) computed  50 / 219 ratios
# 2025-06-14 12:47:59,284 | INFO    |    (base) computed  75 / 219 ratios
# c:\Users\Jason Pohl\miniconda3\lib\site-packages\numpy\lib\function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# c:\Users\Jason Pohl\miniconda3\lib\site-packages\numpy\lib\function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# c:\Users\Jason Pohl\miniconda3\lib\site-packages\numpy\lib\function_base.py:4573: RuntimeWarning: invalid value encountered in subtract
#   diff_b_a = subtract(b, a)
# 2025-06-14 12:48:09,291 | INFO    |    (base) computed 100 / 219 ratios
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 685
#     680     return raw, wins, audit_rows, skips
#     682 # ──────────────────────────────────────────────────────────────────────
#     683 # 9 · EXECUTE BASE & DERIVED PASSES
#     684 # ──────────────────────────────────────────────────────────────────────
# --> 685 raw_base, wins_base, audit_base, skip_base = _run_pass(ratio_funcs, "base")
#     686 df = pd.concat([df,
#     687                 pd.DataFrame(raw_base, index=df.index),
#     688                 pd.DataFrame(wins_base, index=df.index)],
#     689                axis=1)
#     691 raw_der, wins_der, audit_der, skip_der = _run_pass(derived_ratio_funcs, "derived")
#
# Cell In[1], line 665, in _run_pass(func_dict, label)
#     663 for i, (name, fn) in enumerate(func_dict.items(), 1):
#     664     try:
# --> 665         raw_series = _to_series(fn(df), df.index)
#     666     except Exception as err:
#     667         logger.warning("⏭️  %s skipped – %s", name, err)
#
# Cell In[1], line 325, in <lambda>(C)
#     188     df["CommonStockRepurchased"] = 0.0   # numeric fallback
#     190 # ──────────────────────────────────────────────────────────────────────
#     191 # 6 · RATIO DEFINITIONS  (verbatim from user’s library)
#     192 #     – we keep them local for a self-contained file
#     193 # ──────────────────────────────────────────────────────────────────────
#     194 ratio_funcs = {
#     195
#     196     #### PREPARE STAGES
#     197          # ───────────────────────────────────── PHYSICAL · PREPARE
#     198     "Cash_to_Total_Assets":            lambda C: safe_div(C["Cash"].fillna(0), C["TotalAssets"]),
#     199     "Cash_to_Total_Assets_Alt":        lambda C: safe_div(C["CashAndCashEquivalents"].fillna(0), C["TotalAssets"]),
#     200     "Current_Ratio":                   lambda C: safe_div(C["CurrentAssets"], C["CurrentLiabilities"]),
#     201     "Quick_Ratio":                     lambda C: safe_div(C["CurrentAssets"] - C["Inventory"], C["CurrentLiabilities"]),
#     202     "Cash_Ratio":                      lambda C: safe_div(C["CashAndCashEquivalents"], C["CurrentLiabilities"]),
#     203     "Operating_Cash_Flow_Ratio":       lambda C: safe_div(C["OperatingCashFlow"], C.groupby("Symbol")["CurrentLiabilities"].rolling(2).mean().reset_index(level=0, drop=True)),
#     204     "NetWorkingCapital_to_Assets":     lambda C: safe_div(C["CurrentAssets"] - C["CurrentLiabilities"], C["TotalAssets"]),
#     205     "Cash_Conversion_Cycle":           lambda C: C["AccountsReceivableDays"] + C["InventoryDays"] - C["AccountsPayableDays"],
#     206     "Operating_CF_to_Debt":            lambda C: safe_div(C["OperatingCashFlow"], C.groupby("Symbol")["TotalDebt"].rolling(2).mean().reset_index(level=0, drop=True)),
#     207     "NetDebt_to_OCF":                  lambda C: safe_div(C["TotalDebt"] - C["CashAndCashEquivalents"], C["OperatingCashFlow"]),
#     208     "DaysPayablesOutstanding":         lambda C: safe_div(C["AccountsPayable"], safe_div(C["CostOfRevenue"], 365)),
#     209     "WorkingCapital_to_Sales":         lambda C: safe_div(C["CurrentAssets"] - C["CurrentLiabilities"], C["TotalRevenue"]),
#     210     "CashEquivalents_to_CurrentLiab":  lambda C: safe_div(C["CashAndCashEquivalents"], C["CurrentLiabilities"]),
#     211     "AccountsReceivable_Turnover":     lambda C: safe_div(C["TotalRevenue"], C.groupby("Symbol")["AccountsReceivable"].rolling(2).mean().reset_index(level=0, drop=True)),
#     212     "Inventory_Turnover":              lambda C: safe_div(C["CostOfRevenue"], C.groupby("Symbol")["Inventory"].rolling(2).mean().reset_index(level=0, drop=True)),
#     213     "Net_Operating_WC_to_Assets":      lambda C: safe_div(C["AccountsReceivable"] + C["Inventory"] - C["AccountsPayable"], C["TotalAssets"]),
#     214     "CashFlow_to_Debt":                lambda C: safe_div(C["OperatingCashFlow"], C.groupby("Symbol")["TotalDebt"].rolling(2).mean().reset_index(level=0, drop=True)),
#     215     "CashFlow_to_Assets":              lambda C: safe_div(C["OperatingCashFlow"], C["TotalAssets"]),
#     216     "FCF_to_Assets":                   lambda C: safe_div(C["FreeCashFlow"], C["TotalAssets"]),
#     217     "CashFlow_Coverage_of_Interest":   lambda C: safe_div(C["OperatingCashFlow"], C["InterestExpense"]),
#     218     "OCF_to_NetIncome":                lambda C: safe_div(C["OperatingCashFlow"], C["NetIncome"]),
#     219     "DaysSalesOutstanding":            lambda C: safe_div(C["AccountsReceivable"], safe_div(C["TotalRevenue"], 365)),
#     220     "DaysInventoryOutstanding":        lambda C: safe_div(C["Inventory"], safe_div(C["CostOfRevenue"], 365)),
#     221     "OperatingCycle":                  lambda C: safe_div(C["AccountsReceivable"], safe_div(C["TotalRevenue"], 365)) + safe_div(C["Inventory"], safe_div(C["CostOfRevenue"], 365)),
#     222     "BeginningCash_to_Sales":          lambda C: safe_div(C["BeginningCashPosition"], C["TotalRevenue"]),
#     223     "RetainedEarnings_to_Assets":      lambda C: safe_div(C["RetainedEarnings"], C["TotalAssets"]),
#     224     "Deposits_to_Assets":              lambda C: safe_div(C.get("TotalDeposits", 0), C["TotalAssets"]),
#     225     "Cash_Burn_Duration":              lambda C: safe_div(C["CashAndCashEquivalents"], safe_div(C["OperatingExpense"], 365)),
#     226     "WorkingCapital_Days_Trend":       lambda C: C.groupby(C["Symbol"]).apply(lambda g: slope(g["DaysSalesOutstanding"] + g["DaysInventoryOutstanding"] - g["DaysPayablesOutstanding"], 3)).reset_index(level=0, drop=True),
#     227     "Cash_Return_on_Assets":           lambda C: safe_div(C["OperatingCashFlow"], C["TotalAssets"]),
#     228     "CashConversion_Ratio_3yrAvg":     lambda C: C.groupby("Symbol").apply(lambda g: (g["OperatingCashFlow"]/g["NetIncome"]).rolling(3,1).mean()).reset_index(level=0, drop=True),
#     229     "FCF_Margin_3yrAvg":               lambda C: C.groupby("Symbol").apply(lambda g: safe_div(g["FreeCashFlow"].rolling(3,1).mean(), g["TotalRevenue"].rolling(3,1).mean())).reset_index(level=0, drop=True),
#     230     "FCF_Yield_on_Assets":             lambda C: safe_div(C["FreeCashFlow"], C["TotalAssets"]),
#     231     "Operating_Efficiency_Ratio":      lambda C: safe_div(C["OperatingExpense"], C["TotalRevenue"]),
#     232     "WorkingCapital_Turnover":         lambda C: safe_div(C["TotalRevenue"], C["CurrentAssets"] - C["CurrentLiabilities"]),
#     233
#     234     # ─────────────────────────────────── INFORMATION · PREPARE
#     235     "Accrual_Ratio":                   lambda C: safe_div(C["NetIncome"] - C["OperatingCashFlow"], C["TotalAssets"]),
#     236     "Sloan_Accrual_Measure":           lambda C: safe_div(C["NetIncome"] - C["OperatingCashFlow"], C["TotalAssets"]),
#     237     "Cash_Earnings_Ratio":             lambda C: safe_div(C["OperatingCashFlow"], C["NetIncome"]),
#     238     "Net_Operating_Accruals":          lambda C: safe_div(C["NetIncome"] - C["OperatingCashFlow"] - C["Depreciation"], C["TotalAssets"]),
#     239     "Dechow_Dichev_AQ":                lambda C: safe_div(ratio_funcs["Accrual_Ratio"](C), np.abs(C["OperatingCashFlow"])),
#     240     "Percent_Accruals":                lambda C: safe_div(C["NetIncome"] - C["OperatingCashFlow"], C["TotalRevenue"]),
#     241     "Revenue_Quality":                 lambda C: safe_div(C["AccountsReceivable"].diff(), C["TotalRevenue"].diff()),
#     242     "Revenue_Quality_Delta_AR":        lambda C: safe_div(C["AccountsReceivable"].diff(), C["TotalRevenue"].diff()),
#     243     "WC_Accrual_Ratio":                lambda C: safe_div((C["AccountsReceivable"].diff() + C["Inventory"].diff() - C["AccountsPayable"].diff()), C["TotalRevenue"]),
#     244     "DSO_Trend_3yr": lambda C: C.groupby("Symbol")["DaysSalesOutstanding"].transform(lambda x: slope(x, 3)),
#     245     "Inventory_Inflation_3yr": lambda C: C.groupby("Symbol")["DaysInventoryOutstanding"].transform(lambda x: slope(x, 3)),
#     246     "ROA_3yrAvg":                      lambda C: safe_div(C.groupby(C["Symbol"])["NetIncome"].transform(lambda x: x.rolling(3, 1).mean()), C.groupby(C["Symbol"])["TotalAssets"].transform(lambda x: x.rolling(3, 1).mean())),
#     247     "ROE_3yrAvg":                      lambda C: safe_div(C.groupby(C["Symbol"])["NetIncome"].transform(lambda x: x.rolling(3, 1).mean()), C.groupby(C["Symbol"])["TotalEquity"].transform(lambda x: x.rolling(3, 1).mean())),
#     248     "GrossMargin_3yrAvg":              lambda C: safe_div(C.groupby(C["Symbol"])["GrossProfit"].transform(lambda x: x.rolling(3, 1).mean()), C.groupby(C["Symbol"])["TotalRevenue"].transform(lambda x: x.rolling(3, 1).mean())),
#     249     "EBITDA_Margin_3yrAvg":            lambda C: safe_div(C.groupby(C["Symbol"])["EBITDA"].transform(lambda x: x.rolling(3, 1).mean()), C.groupby(C["Symbol"])["TotalRevenue"].transform(lambda x: x.rolling(3, 1).mean())),
#     250     "OCF_Margin_3yrAvg":               lambda C: safe_div(C.groupby(C["Symbol"])["OperatingCashFlow"].transform(lambda x: x.rolling(3, 1).mean()), C.groupby(C["Symbol"])["TotalRevenue"].transform(lambda x: x.rolling(3, 1).mean())),
#     251     "Accruals_to_Sales":               lambda C: safe_div(C["NetIncome"] - C["OperatingCashFlow"], C["TotalRevenue"]),
#     252
#     253     # ───────────────────────────────────── COGNITIVE · PREPARE
#     254     "R_D_Growth_Rate":                 lambda C: C["ResearchAndDevelopment"].pct_change(),
#     255     "R_D_to_Opex":                     lambda C: safe_div(C["ResearchAndDevelopment"], C["OperatingExpense"]),
#     256     "RnD_Plus_CapEx_Intensity":        lambda C: safe_div(C["ResearchAndDevelopment"] + C["CapitalExpenditure"], C["TotalRevenue"]),
#     257     "R&D_Intensity":                   lambda C: safe_div(C["ResearchAndDevelopment"], C["TotalRevenue"]),
#     258     "R_D_3yr_CAGR":                    lambda C: C.groupby(C["Symbol"])["ResearchAndDevelopment"].pct_change(periods=3),
#     259     "Innovation_Ratio":                lambda C: safe_div(C["ResearchAndDevelopment"], C["GrossProfit"]),
#     260     "R_D_Growth":                      lambda C: C.groupby(C["Symbol"])["ResearchAndDevelopment"].pct_change(),
#     261
#     262     # ─────────────────────────────────────── SOCIAL · PREPARE
#     263     "Interest_Coverage_Ratio":         lambda C: safe_div(C["EarningBeforeInterestAndTax"], C["InterestExpense"]),
#     264     "Cash_Interest_Coverage_Ratio":    lambda C: safe_div(C["OperatingCashFlow"], C["InterestExpense"]),
#     265     "EBITDA_Interest_Coverage":        lambda C: safe_div(C["EBITDA"], C["InterestExpense"]),
#     266     "DSCR":                            lambda C: safe_div(C["EBITDA"] - C["CapitalExpenditure"], C["InterestExpense"] + C.get("DebtRepayment", 0)),
#     267     "Debt_to_Assets":                  lambda C: safe_div(C["TotalDebt"], C["TotalAssets"]),
#     268     "EquityRatio":                     lambda C: safe_div(C["TotalEquity"], C["TotalAssets"]),
#     269     "LongTerm_Debt_to_Equity":         lambda C: safe_div(C["LongTermDebt"], C["TotalEquity"]),
#     270     "Net_Debt_to_Equity":              lambda C: safe_div(C["TotalDebt"] - C["Cash"], C["TotalEquity"]),
#     271     "Financial_Leverage":              lambda C: safe_div(C["TotalAssets"], C["TotalEquity"]),
#     272     "Times_Interest_Earned":           lambda C: safe_div(C["EarningBeforeInterestAndTax"], C["InterestExpense"]),
#     273     "Debt_Maturity_Split":             lambda C: safe_div(C["LongTermDebt"], C["TotalDebt"]),
#     274     "InterestCoverage_Cushion": lambda C: safe_div(
#     275     C["EBITDA"].fillna(C.groupby("SectorName")["EBITDA"].transform("median"))
#     276       - C["CapitalExpenditure"].fillna(
#     277             C.groupby("SectorName")["CapitalExpenditure"].transform("median")),
#     278     C["InterestExpense"].fillna(
#     279             C.groupby("SectorName")["InterestExpense"].transform("median"))
#     280 ),
#     281
#     282
#     283     #### ABSORB STAGES
#     284
#     285     # ───────────────────────────────────── PHYSICAL · ABSORB
#     286     "Asset_Turnover_Ratio":            lambda C: safe_div(C["TotalRevenue"], C["TotalAssets"]),
#     287     "Gross_Profit_Margin":             lambda C: safe_div(C["GrossProfit"], C["TotalRevenue"]),
#     288     "ROA":                             lambda C: safe_div(C["NetIncome"], C["TotalAssets"]),
#     289     "Operating_Margin":                lambda C: safe_div(C["OperatingIncome"], C["TotalRevenue"]),
#     290     "EBITDA_Margin":                   lambda C: safe_div(C["EBITDA"], C["TotalRevenue"]),
#     291     "Net_Income_Margin":               lambda C: safe_div(C["NetIncome"], C["TotalRevenue"]),
#     292     "OperatingIncome_Margin":          lambda C: safe_div(C["OperatingIncome"], C["TotalRevenue"]),
#     293     "Cost_of_Revenue_Ratio":           lambda C: safe_div(C["CostOfRevenue"], C["TotalRevenue"]),
#     294     "Operating_Expense_Ratio":         lambda C: safe_div(C["OperatingExpense"], C["TotalRevenue"]),
#     295     "SG_A_to_Revenue":                 lambda C: safe_div(C["SellingGeneralAndAdministration"], C["TotalRevenue"]),
#     296     "EBT_Margin":                      lambda C: safe_div(C["PretaxIncome"], C["TotalRevenue"]),
#     297     "ROCE":                            lambda C: safe_div(C["EarningBeforeInterestAndTax"], C["TotalAssets"] - C["CurrentLiabilities"]),
#     298     "GrossMargin_Stability":           lambda C: (safe_div(C["GrossProfit"], C["TotalRevenue"]).groupby(C["Symbol"]).transform(lambda x: x.rolling(5, 3).std())),
#     299     "Fixed_Asset_Turnover":            lambda C: safe_div(C["TotalRevenue"], C["TotalAssets"] - C["CurrentAssets"]),
#     300     "Inventory_to_Assets":             lambda C: safe_div(C["Inventory"], C["TotalAssets"]),
#     301     "Receivables_to_Assets":           lambda C: safe_div(C["AccountsReceivable"], C["TotalAssets"]),
#     302     "Payables_to_Assets":              lambda C: safe_div(C["AccountsPayable"], C["TotalAssets"]),
#     303     "Operating_Return_on_Opex":        lambda C: safe_div(C["OperatingIncome"], C["OperatingExpense"]),
#     304     "CashFlow_Margin":                 lambda C: safe_div(C["OperatingCashFlow"], C["TotalRevenue"]),
#     305     "CashConversionEfficiency":        lambda C: safe_div(C["OperatingCashFlow"], C["TotalRevenue"]),
#     306     "Operating_Leverage":              lambda C: safe_div(C["OperatingIncome"].pct_change(5), C["TotalRevenue"].pct_change(5)),
#     307     "InvestedCapital_Turnover":        lambda C: safe_div(C["TotalRevenue"], C["InvestedCapital"]),
#     308     "FCF_Margin":                      lambda C: safe_div(C["FreeCashFlow"], C["TotalRevenue"]),
#     309
#     310     # ─────────────────────────────────── INFORMATION · ABSORB
#     311     "Earnings_Volatility":             lambda C: C.groupby(C["Symbol"])["NetIncome"].transform(lambda x: safe_div(x.rolling(5, 2).std(), x.rolling(5, 2).mean())),
#     312     "EBITDA_Volatility":               lambda C: C.groupby(C["Symbol"])["EBITDA"].transform(lambda x: safe_div(x.rolling(5, 2).std(), x.rolling(5, 2).mean())),
#     313     "Earnings_Volatility_AbsMean":     lambda C: C.groupby(C["Symbol"])["NetIncome"].transform(lambda x: safe_div(x.rolling(5, 2).std(), x.rolling(5, 2).apply(lambda y: np.abs(y.mean())))),
#     314     "EBITDA_CV":                       lambda C: C.groupby(C["Symbol"])["EBITDA"].transform(lambda x: safe_div(x.rolling(5, 2).std(), x.rolling(5, 2).mean())),
#     315     "NetIncome_StDev_3yr":             lambda C: C.groupby(C["Symbol"])["NetIncome"].transform(lambda x: x.rolling(3, 2).std()),
#     316     "EBITDA_StDev_3yr":                lambda C: C.groupby(C["Symbol"])["EBITDA"].transform(lambda x: x.rolling(3, 2).std()),
#     317     "Revenue_StDev_3yr":               lambda C: C.groupby(C["Symbol"])["TotalRevenue"].transform(lambda x: x.rolling(3, 2).std()),
#     318     "OCF_StDev_3yr":                   lambda C: C.groupby(C["Symbol"])["OperatingCashFlow"].transform(lambda x: x.rolling(3, 2).std()),
#     319     "ROA_StDev_5yr":                   lambda C: C.groupby(C["Symbol"]).apply(lambda g: safe_div(g["NetIncome"], g["TotalAssets"]).rolling(5, 2).std()).reset_index(level=0, drop=True),
#     320     "EBITDA_Volatility_5yr":           lambda C: C.groupby(C["Symbol"])["EBITDA"].transform(lambda x: safe_div(x.rolling(5, 2).std(), x.rolling(5, 2).mean())),
#     321     "Earnings_Volatility_5yr":         lambda C: C.groupby(C["Symbol"])["NetIncome"].transform(lambda x: safe_div(x.rolling(5, 2).std(), x.rolling(5, 2).mean())),
#     322     "OperatingCF_Volatility_5yr":      lambda C: C.groupby(C["Symbol"])["OperatingCashFlow"].transform(lambda x: safe_div(x.rolling(5, 2).std(), x.rolling(5, 2).mean())),
#     323     "Sales_Volatility_5yr":            lambda C: C.groupby(C["Symbol"])["TotalRevenue"].transform(lambda x: safe_div(x.rolling(5, 2).std(), x.rolling(5, 2).mean())),
#     324     "FCF_Volatility_3yr":              lambda C: C.groupby(C["Symbol"])["FreeCashFlow"].transform(lambda x: x.rolling(3, 2).std()),
# --> 325     "GrossMargin_Volatility":          lambda C: C.groupby(C["Symbol"])["GrossProfit"].transform(lambda x: safe_div((x/C["TotalRevenue"]).rolling(5,2).std(), (x/C["TotalRevenue"]).rolling(5,2).mean())),
#     326
#     327     # ───────────────────────────────────── COGNITIVE · ABSORB
#     328     "Gross_Profitability_Alt":         lambda C: safe_div(C["GrossProfit"], C["NetAssets"]),
#     329     "GrossProfit_to_Equity":           lambda C: safe_div(C["GrossProfit"], C["TotalEquity"]),
#     330     "Price_Premium_Index":             lambda C: safe_div(ratio_funcs["Gross_Profit_Margin"](C), safe_div(C["GrossProfit"], C["TotalRevenue"]).groupby(C["SectorName"]).transform("median")),
#     331
#     332     # ─────────────────────────────────────── SOCIAL · ABSORB
#     333     "LT_Debt_to_EBITDA":               lambda C: safe_div(C["LongTermDebt"], C["EBITDA"]),
#     334     "InterestBearingDebt_to_EBITDA":   lambda C: safe_div(C["TotalDebt"], C["EBITDA"]),
#     335     "Net_Debt_to_EBITDA":              lambda C: safe_div(C["TotalDebt"] - C["CashAndCashEquivalents"], C["EBITDA"]),
#     336     "LT_Debt_to_TotalDebt":            lambda C: safe_div(C["LongTermDebt"], C["TotalDebt"]),
#     337     "Effective_Tax_Rate":              lambda C: safe_div(C["IncomeTaxExpense"], C["PretaxIncome"]),
#     338     "InterestExpense_to_Sales":        lambda C: safe_div(C["InterestExpense"], C["TotalRevenue"]),
#     339     "InterestCoverage_Volatility_5yr": lambda C: C.groupby(C["Symbol"]).apply(lambda g: safe_div((g["EarningBeforeInterestAndTax"]/g["InterestExpense"]).rolling(5, 2).std(), (g["EarningBeforeInterestAndTax"]/g["InterestExpense"]).rolling(5, 2).mean())).reset_index(level=0, drop=True),
#     340     "InterestCoverage_Volatility_3yr": lambda C: C.groupby(C["Symbol"]).apply(lambda g: safe_div((g["EarningBeforeInterestAndTax"]/g["InterestExpense"]).rolling(3, 2).std(), (g["EarningBeforeInterestAndTax"]/g["InterestExpense"]).rolling(3, 2).mean())).reset_index(level=0, drop=True),
#     341
#     342
#     343     #### RECOVER STAGES
#     344
#     345     # ───────────────────────────────────── PHYSICAL · RECOVER
#     346     "ROE":                             lambda C: safe_div(C["NetIncome"], C["TotalEquity"]),
#     347     "Debt_to_Equity":                  lambda C: safe_div(C["TotalDebt"], C["TotalEquity"]),
#     348     "Debt_to_Equity_Liab":             lambda C: safe_div(C["TotalLiabilitiesAsReported"], C["TotalEquity"]),
#     349     "EPS":                             lambda C: safe_div(C["NetIncome"], C["BasicAverageShares"]),
#     350     "Cash_Dividends_to_Net_Income":    lambda C: safe_div(C["CashDividendsPaid"], C["NetIncome"]),
#     351     "Return_on_Tangible_Equity":       lambda C: safe_div(C["NetIncome"], C["TotalEquity"] - C["Goodwill"]),
#     352     "Total_Payout_Ratio":              lambda C: safe_div(C.get("CashDividendsPaid", 0) + C.get("CommonStockRepurchased", 0), C["NetIncome"]),
#     353     "NetDebt_PayDown_Rate":            lambda C: safe_div(-(C["TotalDebt"] - C["CashAndCashEquivalents"]).diff(), C["TotalDebt"]),
#     354     "Incremental_ROIC":                lambda C: safe_div(C["NetIncome"].diff() + C["InterestExpense"].diff() * (1 - 0.30), (C["TotalDebt"] + C["TotalEquity"] - C["Cash"]).diff()),
#     355     "ROIC_Slope_5yr":                  lambda C: C.groupby(C["Symbol"])["ROIC"].transform(lambda x: slope(x, 5)),
#     356     "ROIC_Slope_3yr":                  lambda C: C.groupby(C["Symbol"])["ROIC"].transform(lambda x: slope(x, 3)),
#     357     "ROIC_Trend_5yr_Slope":            lambda C: C.groupby(C["Symbol"])["ROIC"].transform(lambda x: slope(x, 5)),
#     358     "ROIC_Trend_3yr_Slope":            lambda C: C.groupby(C["Symbol"])["ROIC"].transform(lambda x: slope(x, 3)),
#     359     "ROIC_3yr_Avg":                    lambda C: C.groupby(C["Symbol"])["ROIC"].transform(lambda x: x.rolling(3, 1).mean()),
#     360     "ROIC_5yr_Median":                 lambda C: C.groupby(C["Symbol"])["ROIC"].transform(lambda x: x.rolling(5, 1).median()),
#     361     "ROIC_3yr_Median":                 lambda C: C.groupby(C["Symbol"])["ROIC"].transform(lambda x: x.rolling(3, 1).median()),
#     362     "EBITDA_DropThrough":              lambda C: safe_div(C["EBITDA"].diff(), C["TotalRevenue"].diff()),
#     363     "OperatingLeverage_Slope":         lambda C: C.groupby(C["Symbol"]).apply(lambda g: slope((g["OperatingIncome"].pct_change()) / (g["TotalRevenue"].pct_change()), 5)).reset_index(level=0, drop=True),
#     364     "Revenue_Recovery_Rate":           lambda C: safe_div(C.groupby(C["Symbol"])["TotalRevenue"].shift(-1), C["TotalRevenue"]),
#     365     "Retention_to_Growth":             lambda C: safe_div(C["RetainedEarnings"], C["TotalRevenue"].diff()),
#     366
#     367     # ─────────────────────────────────── INFORMATION · RECOVER
#     368     "Advertising_to_Sales":            lambda C: safe_div(C["SellingAndMarketingExpense"].fillna(0), C["TotalRevenue"]),
#     369     "Marketing_Efficiency_Ratio":      lambda C: safe_div(C["TotalRevenue"] - C["CostOfRevenue"] - C["SellingAndMarketingExpense"], C["SellingAndMarketingExpense"]),
#     370     "Combined_SellingExpense_to_Sales":lambda C: safe_div(C["SellingAndMarketingExpense"], C["TotalRevenue"]),
#     371     "SGA_to_Sales":                    lambda C: safe_div(C["SellingGeneralAndAdministration"], C["TotalRevenue"]),
#     372     "Advertising_to_Sales_3yrCAGR":    lambda C: ratio_funcs["Advertising_to_Sales"](C).groupby(C["Symbol"]).pct_change(3),
#     373     "OperatingMargin_Delta":           lambda C: (C["OperatingIncome"]/C["TotalRevenue"]) - (C["OperatingIncome"].shift(1)/C["TotalRevenue"].shift(1)),
#     374     "OperatingMargin_Slope_5yr":       lambda C: C.groupby(C["Symbol"]).apply(lambda g: slope(g["OperatingIncome"]/g["TotalRevenue"], 5)).reset_index(level=0, drop=True),
#     375     "OperatingMargin_Slope_3yr":       lambda C: C.groupby(C["Symbol"]).apply(lambda g: slope(g["OperatingIncome"]/g["TotalRevenue"], 3)).reset_index(level=0, drop=True),
#     376     "EBITDA_Margin_StdDev_5yr":        lambda C: C.groupby(C["Symbol"])["EBITDA"].transform(lambda x: (x/C["TotalRevenue"]).rolling(5,2).std()),
#     377     "EBITDA_Margin_StdDev_3yr":        lambda C: C.groupby(C["Symbol"])["EBITDA"].transform(lambda x: (x/C["TotalRevenue"]).rolling(3,2).std()),
#     378     "EPS_Volatility_5yr":              lambda C: C.groupby(C["Symbol"])["BasicEPS"].transform(lambda x: safe_div(x.rolling(5,2).std(), x.rolling(5,2).mean().abs())),
#     379     "EPS_Volatility_3yr":              lambda C: C.groupby(C["Symbol"])["BasicEPS"].transform(lambda x: safe_div(x.rolling(3,2).std(), x.rolling(3,2).mean().abs())),
#     380     "EPS_Growth":                      lambda C: safe_div(C["BasicEPS"].diff(), C["BasicEPS"].shift(1)),
#     381     "EPS_Stability":                   lambda C: C.groupby(C["Symbol"])["BasicEPS"].transform(lambda x: safe_div(x.rolling(5,2).std(), x.rolling(5,2).mean().abs())),
#     382     "ROE_StdDev_5yr":                  lambda C: C.groupby(C["Symbol"])["NetIncome"].transform(lambda x: safe_div(x.rolling(5,2).std(), C["TotalEquity"].rolling(5,2).mean())),
#     383     "ROE_StdDev_3yr":                  lambda C: C.groupby(C["Symbol"])["NetIncome"].transform(lambda x: safe_div(x.rolling(3,2).std(), C["TotalEquity"].rolling(3,2).mean())),
#     384
#     385     # ───────────────────────────────────── COGNITIVE · RECOVER
#     386     "NOPAT_Alt":                       lambda C: safe_div(C["NetIncome"] + C["InterestExpense"] * (1 - C.get("EffectiveTaxRateAsReported", 0.30)), C["TotalRevenue"]),
#     387     "NOPAT_to_Avg_InvestedCapital":    lambda C: safe_div(C["NetIncome"] + C["InterestExpense"] * (1 - 0.30), (C["TotalDebt"] + C["TotalEquity"] - C["Cash"]).rolling(2).mean()),
#     388     "ROIC":                            lambda C: safe_div(C["EarningBeforeInterestAndTax"], C["TotalDebt"] + C["TotalEquity"] - C["Cash"]),
#     389
#     390     # ─────────────────────────────────────── SOCIAL · RECOVER
#     391     "Equity_Issuance_Rate":            lambda C: safe_div(C["IssuanceOfCapitalStock"], C["TotalEquity"]),
#     392     "Share_Issuance_Rate":             lambda C: safe_div(C["BasicAverageShares"].diff(), C["BasicAverageShares"].shift(1)),
#     393     "Share_Dilution_3yrChg":           lambda C: safe_div(C["BasicAverageShares"], C.groupby(C["Symbol"])["BasicAverageShares"].shift(3)) - 1,
#     394
#     395     #### ADAPT STAGES
#     396
#     397      # ───────────────────────────────────── PHYSICAL · ADAPT
#     398     "CapEx_to_Sales":                  lambda C: safe_div(C["CapitalExpenditure"], C["TotalRevenue"]),
#     399     "CapEx_to_Depreciation":           lambda C: safe_div(C["CapitalExpenditure"], C["Depreciation"]),
#     400     "CapEx_plus_RnD_to_Sales":         lambda C: safe_div(C["CapitalExpenditure"] + C["ResearchAndDevelopment"], C["TotalRevenue"]),
#     401     "CapEx_GrowthRate":                lambda C: C.groupby(C["Symbol"])["CapitalExpenditure"].pct_change(),
#     402     "CapEx_Dep_Growth":                lambda C: safe_div(C["CapitalExpenditure"], C["Depreciation"]).pct_change(),
#     403     "Maintenance_CapEx_Ratio":         lambda C: safe_div(C["CapitalExpenditure"], C["Depreciation"]),
#     404     "FreeCashFlow_to_InvestedCapital": lambda C: safe_div(C["FreeCashFlow"], C["InvestedCapital"]),
#     405     "CapitalisedSoftware_to_Assets":   lambda C: safe_div(C.get("SoftwareIntangibles", 0), C["TotalAssets"]),
#     406     "Acquisitions_to_OCF":             lambda C: safe_div(C.get("AcquisitionsCashOutflow", 0), C["OperatingCashFlow"]),
#     407     "Reinvestment_Rate":               lambda C: safe_div(C["CapitalExpenditure"] - C["Depreciation"], C["OperatingCashFlow"]),
#     408     "CapEx_Variability_5yr":           lambda C: C.groupby(C["Symbol"])["CapitalExpenditure"].transform(lambda x: safe_div(x.rolling(5, 2).std(), x.rolling(5, 2).mean())),
#     409     "CapEx_Variability_3yr":           lambda C: C.groupby(C["Symbol"])["CapitalExpenditure"].transform(lambda x: safe_div(x.rolling(3, 2).std(), x.rolling(3, 2).mean())),
#     410     "OCF_to_CapEx":                    lambda C: safe_div(C["OperatingCashFlow"], C["CapitalExpenditure"]),
#     411     "OCF_FreeCash_Cushion":            lambda C: safe_div(C["OperatingCashFlow"] - C["CapitalExpenditure"] - C["CashDividendsPaid"], C["TotalRevenue"]),
#     412
#     413     # ─────────────────────────────────── INFORMATION · ADAPT
#     414     "Retention_Ratio":                 lambda C: 1 - safe_div(C["CashDividendsPaid"], C["NetIncome"]),
#     415     "Gross_Profitability":             lambda C: safe_div(C["GrossProfit"], C["TotalAssets"]),
#     416     "NOPAT_Margin":                    lambda C: safe_div(C["NetIncome"] + C["InterestExpense"] * (1 - 0.30), C["TotalRevenue"]),
#     417     "Sustainable_Growth_Rate":         lambda C: safe_div(C["NetIncome"], C["TotalEquity"]) * (1 - safe_div(C["CashDividendsPaid"], C["NetIncome"])),
#     418     "Revenue_CAGR_5yr":                lambda C: (safe_div(C["TotalRevenue"], C.groupby(C["Symbol"])["TotalRevenue"].shift(5)))**0.2 - 1,
#     419     "Revenue_CAGR_3yr":                lambda C: (safe_div(C["TotalRevenue"], C.groupby(C["Symbol"])["TotalRevenue"].shift(3)))**(1/3) - 1,
#     420     "Revenue_Growth":                  lambda C: C.groupby(C["Symbol"])["TotalRevenue"].pct_change(),
#     421     "NetIncome_Growth":                lambda C: C.groupby(C["Symbol"])["NetIncome"].pct_change(),
#     422     "EBITDA_Growth":                   lambda C: C.groupby(C["Symbol"])["EBITDA"].pct_change(),
#     423     "Assets_Growth":                   lambda C: C.groupby(C["Symbol"])["TotalAssets"].pct_change(),
#     424     "Equity_Growth":                   lambda C: C.groupby(C["Symbol"])["TotalEquity"].pct_change(),
#     425     "OCF_Growth":                      lambda C: C.groupby(C["Symbol"])["OperatingCashFlow"].pct_change(),
#     426     "FCF_Growth":                      lambda C: safe_div(C["FreeCashFlow"].diff(), C["FreeCashFlow"].shift(1)),
#     427     "FCF_Growth_3yrCAGR":              lambda C: (safe_div(C["FreeCashFlow"], C.groupby(C["Symbol"])["FreeCashFlow"].shift(3)))**(1/3) - 1,
#     428     "OCF_CAGR_5yr":                    lambda C: safe_div(C["OperatingCashFlow"], C.groupby(C["Symbol"])["OperatingCashFlow"].shift(5))**0.2 - 1,
#     429     "OCF_CAGR_3yr":                    lambda C: safe_div(C["OperatingCashFlow"], C.groupby(C["Symbol"])["OperatingCashFlow"].shift(3))**(1/3) - 1,
#     430     "Dividend_Growth":                 lambda C: C.groupby(C["Symbol"])["DividendPerShare"].pct_change(),
#     431     "Dividend_Growth_Alt":             lambda C: C.groupby(C["Symbol"])["CashDividendsPaid"].pct_change(),
#     432     "CapEx_Growth":                    lambda C: C.groupby(C["Symbol"])["CapitalExpenditure"].pct_change(),
#     433     "GrossProfit_Growth":              lambda C: C.groupby(C["Symbol"])["GrossProfit"].pct_change(),
#     434     "OCF_Volatility_3yr":              lambda C: C.groupby(C["Symbol"])["OperatingCashFlow"].transform(lambda x: safe_div(x.rolling(3,2).std(), x.rolling(3,2).mean())),
#     435     "CashFlow_Skewness":               lambda C: C.groupby(C["Symbol"])["OperatingCashFlow"].transform(lambda x: skew(x, 5)),
#     436     "FCF_Volatility_5yr":              lambda C: C.groupby(C["Symbol"])["FreeCashFlow"].transform(lambda x: safe_div(x.rolling(5,2).std(), x.rolling(5,2).mean())),
#     437     "OCF_Margin":                      lambda C: safe_div(C["OperatingCashFlow"], C["TotalRevenue"]),
#     438
#     439     # ───────────────────────────────────── COGNITIVE · ADAPT
#     440     "Market_Share_Ratio":              lambda C: safe_div(C["TotalRevenue"], C.groupby(C["SectorName"])["TotalRevenue"].transform("sum")),
#     441     "Relative_Revenue_Growth_vs_Sector": lambda C: C.groupby(C["SectorName"])["TotalRevenue"].pct_change() - C.groupby(C["Symbol"])["TotalRevenue"].pct_change(),
#     442     "Market_Share_Revenue_Change":     lambda C: safe_div(C["TotalRevenue"], C.groupby(C["SectorName"])["TotalRevenue"].transform("sum")),
#     443     "Market_Share_EBITDA_Change":      lambda C: safe_div(C["EBITDA"], C.groupby(C["SectorName"])["EBITDA"].transform("sum")),
#     444     "Relative_EBITDA_Growth_vs_Sector": lambda C: C.groupby(C["SectorName"])["EBITDA"].pct_change() - C.groupby(C["Symbol"])["EBITDA"].pct_change(),
#     445     "Relative_OperatingIncome_Growth_vs_Sector": lambda C: C.groupby(C["SectorName"])["OperatingIncome"].pct_change() - C.groupby(C["Symbol"])["OperatingIncome"].pct_change(),
#     446     "Market_Share_OperatingIncome_Change": lambda C: safe_div(C["OperatingIncome"], C.groupby(C["SectorName"])["OperatingIncome"].transform("sum")),
#     447     "Rev_CAGR_vs_Sector":              lambda C: C.groupby(C["SectorName"])["TotalRevenue"].transform(lambda x: x.pct_change(periods=3)),
#     448     "Relative_Revenue_Growth_Sector":  lambda C: C.groupby(C["SectorName"])["TotalRevenue"].pct_change(),
#     449     "Relative_EBITDA_Growth_Sector":   lambda C: C.groupby(C["SectorName"])["EBITDA"].pct_change(),
#     450     "Market_Share_of_Revenue":         lambda C: safe_div(C["TotalRevenue"], C.groupby(C["SectorName"])["TotalRevenue"].transform("sum")),
#     451     "Revenue_Sector_Share_Growth":     lambda C: ratio_funcs["Market_Share_of_Revenue"](C).groupby(C["Symbol"]).pct_change(),
#     452     "EBITDA_Sector_Share":             lambda C: safe_div(C["EBITDA"], C.groupby(C["SectorName"])["EBITDA"].transform("sum")),
#     453     "Relative_OperatingIncome_Growth_Sector": lambda C: C.groupby(C["SectorName"])["OperatingIncome"].pct_change(),
#     454     "Relative_NetIncome_Growth_Sector":       lambda C: C.groupby(C["SectorName"])["NetIncome"].pct_change(),
#     455     "NetIncome_Sector_Share":                 lambda C: safe_div(C["NetIncome"], C.groupby(C["SectorName"])["NetIncome"].transform("sum")),
#     456     "Sales_to_TotalAssets":            lambda C: safe_div(C["TotalRevenue"], C["TotalAssets"]),
#     457     "Sales_to_Marketing_Leverage":     lambda C: safe_div(C["TotalRevenue"].pct_change(), C["SellingAndMarketingExpense"].pct_change()),
#     458     "GrossMargin_Slope_5yr":           lambda C: C.groupby(C["Symbol"]).apply(lambda g: slope(g["GrossProfit"]/g["TotalRevenue"], 5)).reset_index(level=0, drop=True),
#     459     "GrossMargin_Slope_3yr":           lambda C: C.groupby(C["Symbol"]).apply(lambda g: slope(g["GrossProfit"]/g["TotalRevenue"], 3)).reset_index(level=0, drop=True),
#     460     "Price_Realisation_Index":         lambda C: (C["GrossProfit"]/C["TotalRevenue"]).diff() - safe_div(C["CostOfRevenue"].diff(), C["TotalRevenue"].shift(1)),
#     461
#     462     # ─────────────────────────────────────── SOCIAL · ADAPT
#     463     "DPS_to_EPS":                      lambda C: safe_div(C["DividendPerShare"], C.get("BasicEPS", pd.Series(np.nan))),
#     464     "Dividend_Payout_Ratio":           lambda C: safe_div(C["CashDividendsPaid"], C["NetIncome"]),
#     465     "FCF_Payout_Ratio":                lambda C: safe_div(C["CashDividendsPaid"], C["FreeCashFlow"]),
#     466     "Dividend_Stability_Index":        lambda C: C.groupby(C["Symbol"])["CashDividendsPaid"].transform(lambda x: x.notna().rolling(10, 1).sum() / 10),
#     467     "Dividend_Yield_on_FCF":           lambda C: safe_div(C["CashDividendsPaid"], C["FreeCashFlow"]),
#     468     "Dividend_Coverage":               lambda C: safe_div(C["OperatingCashFlow"], C["CashDividendsPaid"]),
#     469     "Dividend_Coverage_FCF":           lambda C: safe_div(C["OperatingCashFlow"] - C["CapitalExpenditure"], C["CashDividendsPaid"]),
#     470     "Dividend_Payout_CV":              lambda C: C.groupby(C["Symbol"]).apply(lambda g: safe_div((g["CashDividendsPaid"]/g["NetIncome"]).rolling(5,2).std(), (g["CashDividendsPaid"]/g["NetIncome"]).rolling(5,2).mean())).reset_index(level=0, drop=True),
#     471     "Share_Count_Reduction_YoY":       lambda C: -safe_div(C["BasicAverageShares"].diff(), C["BasicAverageShares"].shift(1)),
#     472     "Share_Dilution_3yrChg":           lambda C: safe_div(C["BasicAverageShares"], C.groupby(C["Symbol"])["BasicAverageShares"].shift(3)) - 1,
#     473     "Net_Buyback_to_FCF":              lambda C: safe_div(C.get("CommonStockRepurchased", 0) - C.get("IssuanceOfCapitalStock", 0), C["FreeCashFlow"]),
#     474 }
#     476 derived_ratio_funcs = {
#     477     # ── ratios that need ROIC ──
#     478     "ROIC_Slope_5yr"        : ratio_funcs.pop("ROIC_Slope_5yr"),
#    (...)
#     493     "Revenue_Sector_Share_Growth" : ratio_funcs.pop("Revenue_Sector_Share_Growth"),
#     494 }
#     496 # ------------------------------------------------------------------------------
#     497 # 1 ░░  DOMAIN-STAGE MAP  ░░  (165 keys)
#     498 # ------------------------------------------------------------------------------
#
# File c:\Users\Jason Pohl\miniconda3\lib\site-packages\pandas\core\groupby\generic.py:469, in SeriesGroupBy.transform(self, func, engine, engine_kwargs, *args, **kwargs)
#     466 @Substitution(klass="Series", example=__examples_series_doc)
#     467 @Appender(_transform_template)
#     468 def transform(self, func, *args, engine=None, engine_kwargs=None, **kwargs):
# --> 469     return self._transform(
#     470         func, *args, engine=engine, engine_kwargs=engine_kwargs, **kwargs
#     471     )
#
# File c:\Users\Jason Pohl\miniconda3\lib\site-packages\pandas\core\groupby\groupby.py:1530, in GroupBy._transform(self, func, engine, engine_kwargs, *args, **kwargs)
#    1527 func = com.get_cython_func(func) or func
#    1529 if not isinstance(func, str):
# -> 1530     return self._transform_general(func, *args, **kwargs)
#    1532 elif func not in base.transform_kernel_allowlist:
#    1533     msg = f"'{func}' is not a valid function name for transform(name)"
#
# File c:\Users\Jason Pohl\miniconda3\lib\site-packages\pandas\core\groupby\generic.py:503, in SeriesGroupBy._transform_general(self, func, *args, **kwargs)
#     498 for name, group in self.grouper.get_iterator(
#     499     self._selected_obj, axis=self.axis
#     500 ):
#     501     # this setattr is needed for test_transform_lambda_with_datetimetz
#     502     object.__setattr__(group, "name", name)
# --> 503     res = func(group, *args, **kwargs)
#     505     results.append(klass(res, index=group.index))
#     507 # check for empty "results" to avoid concat ValueError
#
# Cell In[1], line 325, in <lambda>(x)
#     188     df["CommonStockRepurchased"] = 0.0   # numeric fallback
#     190 # ──────────────────────────────────────────────────────────────────────
#     191 # 6 · RATIO DEFINITIONS  (verbatim from user’s library)
#     192 #     – we keep them local for a self-contained file
#     193 # ──────────────────────────────────────────────────────────────────────
#     194 ratio_funcs = {
#     195
#     196     #### PREPARE STAGES
#     197          # ───────────────────────────────────── PHYSICAL · PREPARE
#     198     "Cash_to_Total_Assets":            lambda C: safe_div(C["Cash"].fillna(0), C["TotalAssets"]),
#     199     "Cash_to_Total_Assets_Alt":        lambda C: safe_div(C["CashAndCashEquivalents"].fillna(0), C["TotalAssets"]),
#     200     "Current_Ratio":                   lambda C: safe_div(C["CurrentAssets"], C["CurrentLiabilities"]),
#     201     "Quick_Ratio":                     lambda C: safe_div(C["CurrentAssets"] - C["Inventory"], C["CurrentLiabilities"]),
#     202     "Cash_Ratio":                      lambda C: safe_div(C["CashAndCashEquivalents"], C["CurrentLiabilities"]),
#     203     "Operating_Cash_Flow_Ratio":       lambda C: safe_div(C["OperatingCashFlow"], C.groupby("Symbol")["CurrentLiabilities"].rolling(2).mean().reset_index(level=0, drop=True)),
#     204     "NetWorkingCapital_to_Assets":     lambda C: safe_div(C["CurrentAssets"] - C["CurrentLiabilities"], C["TotalAssets"]),
#     205     "Cash_Conversion_Cycle":           lambda C: C["AccountsReceivableDays"] + C["InventoryDays"] - C["AccountsPayableDays"],
#     206     "Operating_CF_to_Debt":            lambda C: safe_div(C["OperatingCashFlow"], C.groupby("Symbol")["TotalDebt"].rolling(2).mean().reset_index(level=0, drop=True)),
#     207     "NetDebt_to_OCF":                  lambda C: safe_div(C["TotalDebt"] - C["CashAndCashEquivalents"], C["OperatingCashFlow"]),
#     208     "DaysPayablesOutstanding":         lambda C: safe_div(C["AccountsPayable"], safe_div(C["CostOfRevenue"], 365)),
#     209     "WorkingCapital_to_Sales":         lambda C: safe_div(C["CurrentAssets"] - C["CurrentLiabilities"], C["TotalRevenue"]),
#     210     "CashEquivalents_to_CurrentLiab":  lambda C: safe_div(C["CashAndCashEquivalents"], C["CurrentLiabilities"]),
#     211     "AccountsReceivable_Turnover":     lambda C: safe_div(C["TotalRevenue"], C.groupby("Symbol")["AccountsReceivable"].rolling(2).mean().reset_index(level=0, drop=True)),
#     212     "Inventory_Turnover":              lambda C: safe_div(C["CostOfRevenue"], C.groupby("Symbol")["Inventory"].rolling(2).mean().reset_index(level=0, drop=True)),
#     213     "Net_Operating_WC_to_Assets":      lambda C: safe_div(C["AccountsReceivable"] + C["Inventory"] - C["AccountsPayable"], C["TotalAssets"]),
#     214     "CashFlow_to_Debt":                lambda C: safe_div(C["OperatingCashFlow"], C.groupby("Symbol")["TotalDebt"].rolling(2).mean().reset_index(level=0, drop=True)),
#     215     "CashFlow_to_Assets":              lambda C: safe_div(C["OperatingCashFlow"], C["TotalAssets"]),
#     216     "FCF_to_Assets":                   lambda C: safe_div(C["FreeCashFlow"], C["TotalAssets"]),
#     217     "CashFlow_Coverage_of_Interest":   lambda C: safe_div(C["OperatingCashFlow"], C["InterestExpense"]),
#     218     "OCF_to_NetIncome":                lambda C: safe_div(C["OperatingCashFlow"], C["NetIncome"]),
#     219     "DaysSalesOutstanding":            lambda C: safe_div(C["AccountsReceivable"], safe_div(C["TotalRevenue"], 365)),
#     220     "DaysInventoryOutstanding":        lambda C: safe_div(C["Inventory"], safe_div(C["CostOfRevenue"], 365)),
#     221     "OperatingCycle":                  lambda C: safe_div(C["AccountsReceivable"], safe_div(C["TotalRevenue"], 365)) + safe_div(C["Inventory"], safe_div(C["CostOfRevenue"], 365)),
#     222     "BeginningCash_to_Sales":          lambda C: safe_div(C["BeginningCashPosition"], C["TotalRevenue"]),
#     223     "RetainedEarnings_to_Assets":      lambda C: safe_div(C["RetainedEarnings"], C["TotalAssets"]),
#     224     "Deposits_to_Assets":              lambda C: safe_div(C.get("TotalDeposits", 0), C["TotalAssets"]),
#     225     "Cash_Burn_Duration":              lambda C: safe_div(C["CashAndCashEquivalents"], safe_div(C["OperatingExpense"], 365)),
#     226     "WorkingCapital_Days_Trend":       lambda C: C.groupby(C["Symbol"]).apply(lambda g: slope(g["DaysSalesOutstanding"] + g["DaysInventoryOutstanding"] - g["DaysPayablesOutstanding"], 3)).reset_index(level=0, drop=True),
#     227     "Cash_Return_on_Assets":           lambda C: safe_div(C["OperatingCashFlow"], C["TotalAssets"]),
#     228     "CashConversion_Ratio_3yrAvg":     lambda C: C.groupby("Symbol").apply(lambda g: (g["OperatingCashFlow"]/g["NetIncome"]).rolling(3,1).mean()).reset_index(level=0, drop=True),
#     229     "FCF_Margin_3yrAvg":               lambda C: C.groupby("Symbol").apply(lambda g: safe_div(g["FreeCashFlow"].rolling(3,1).mean(), g["TotalRevenue"].rolling(3,1).mean())).reset_index(level=0, drop=True),
#     230     "FCF_Yield_on_Assets":             lambda C: safe_div(C["FreeCashFlow"], C["TotalAssets"]),
#     231     "Operating_Efficiency_Ratio":      lambda C: safe_div(C["OperatingExpense"], C["TotalRevenue"]),
#     232     "WorkingCapital_Turnover":         lambda C: safe_div(C["TotalRevenue"], C["CurrentAssets"] - C["CurrentLiabilities"]),
#     233
#     234     # ─────────────────────────────────── INFORMATION · PREPARE
#     235     "Accrual_Ratio":                   lambda C: safe_div(C["NetIncome"] - C["OperatingCashFlow"], C["TotalAssets"]),
#     236     "Sloan_Accrual_Measure":           lambda C: safe_div(C["NetIncome"] - C["OperatingCashFlow"], C["TotalAssets"]),
#     237     "Cash_Earnings_Ratio":             lambda C: safe_div(C["OperatingCashFlow"], C["NetIncome"]),
#     238     "Net_Operating_Accruals":          lambda C: safe_div(C["NetIncome"] - C["OperatingCashFlow"] - C["Depreciation"], C["TotalAssets"]),
#     239     "Dechow_Dichev_AQ":                lambda C: safe_div(ratio_funcs["Accrual_Ratio"](C), np.abs(C["OperatingCashFlow"])),
#     240     "Percent_Accruals":                lambda C: safe_div(C["NetIncome"] - C["OperatingCashFlow"], C["TotalRevenue"]),
#     241     "Revenue_Quality":                 lambda C: safe_div(C["AccountsReceivable"].diff(), C["TotalRevenue"].diff()),
#     242     "Revenue_Quality_Delta_AR":        lambda C: safe_div(C["AccountsReceivable"].diff(), C["TotalRevenue"].diff()),
#     243     "WC_Accrual_Ratio":                lambda C: safe_div((C["AccountsReceivable"].diff() + C["Inventory"].diff() - C["AccountsPayable"].diff()), C["TotalRevenue"]),
#     244     "DSO_Trend_3yr": lambda C: C.groupby("Symbol")["DaysSalesOutstanding"].transform(lambda x: slope(x, 3)),
#     245     "Inventory_Inflation_3yr": lambda C: C.groupby("Symbol")["DaysInventoryOutstanding"].transform(lambda x: slope(x, 3)),
#     246     "ROA_3yrAvg":                      lambda C: safe_div(C.groupby(C["Symbol"])["NetIncome"].transform(lambda x: x.rolling(3, 1).mean()), C.groupby(C["Symbol"])["TotalAssets"].transform(lambda x: x.rolling(3, 1).mean())),
#     247     "ROE_3yrAvg":                      lambda C: safe_div(C.groupby(C["Symbol"])["NetIncome"].transform(lambda x: x.rolling(3, 1).mean()), C.groupby(C["Symbol"])["TotalEquity"].transform(lambda x: x.rolling(3, 1).mean())),
#     248     "GrossMargin_3yrAvg":              lambda C: safe_div(C.groupby(C["Symbol"])["GrossProfit"].transform(lambda x: x.rolling(3, 1).mean()), C.groupby(C["Symbol"])["TotalRevenue"].transform(lambda x: x.rolling(3, 1).mean())),
#     249     "EBITDA_Margin_3yrAvg":            lambda C: safe_div(C.groupby(C["Symbol"])["EBITDA"].transform(lambda x: x.rolling(3, 1).mean()), C.groupby(C["Symbol"])["TotalRevenue"].transform(lambda x: x.rolling(3, 1).mean())),
#     250     "OCF_Margin_3yrAvg":               lambda C: safe_div(C.groupby(C["Symbol"])["OperatingCashFlow"].transform(lambda x: x.rolling(3, 1).mean()), C.groupby(C["Symbol"])["TotalRevenue"].transform(lambda x: x.rolling(3, 1).mean())),
#     251     "Accruals_to_Sales":               lambda C: safe_div(C["NetIncome"] - C["OperatingCashFlow"], C["TotalRevenue"]),
#     252
#     253     # ───────────────────────────────────── COGNITIVE · PREPARE
#     254     "R_D_Growth_Rate":                 lambda C: C["ResearchAndDevelopment"].pct_change(),
#     255     "R_D_to_Opex":                     lambda C: safe_div(C["ResearchAndDevelopment"], C["OperatingExpense"]),
#     256     "RnD_Plus_CapEx_Intensity":        lambda C: safe_div(C["ResearchAndDevelopment"] + C["CapitalExpenditure"], C["TotalRevenue"]),
#     257     "R&D_Intensity":                   lambda C: safe_div(C["ResearchAndDevelopment"], C["TotalRevenue"]),
#     258     "R_D_3yr_CAGR":                    lambda C: C.groupby(C["Symbol"])["ResearchAndDevelopment"].pct_change(periods=3),
#     259     "Innovation_Ratio":                lambda C: safe_div(C["ResearchAndDevelopment"], C["GrossProfit"]),
#     260     "R_D_Growth":                      lambda C: C.groupby(C["Symbol"])["ResearchAndDevelopment"].pct_change(),
#     261
#     262     # ─────────────────────────────────────── SOCIAL · PREPARE
#     263     "Interest_Coverage_Ratio":         lambda C: safe_div(C["EarningBeforeInterestAndTax"], C["InterestExpense"]),
#     264     "Cash_Interest_Coverage_Ratio":    lambda C: safe_div(C["OperatingCashFlow"], C["InterestExpense"]),
# ...
#     381     "EPS_Stability":                   lambda C: C.groupby(C["Symbol"])["BasicEPS"].transform(lambda x: safe_div(x.rolling(5,2).std(), x.rolling(5,2).mean().abs())),
#     382     "ROE_StdDev_5yr":                  lambda C: C.groupby(C["Symbol"])["NetIncome"].transform(lambda x: safe_div(x.rolling(5,2).std(), C["TotalEquity"].rolling(5,2).mean())),
#     383     "ROE_StdDev_3yr":                  lambda C: C.groupby(C["Symbol"])["NetIncome"].transform(lambda x: safe_div(x.rolling(3,2).std(), C["TotalEquity"].rolling(3,2).mean())),
#     384
#     385     # ───────────────────────────────────── COGNITIVE · RECOVER
#     386     "NOPAT_Alt":                       lambda C: safe_div(C["NetIncome"] + C["InterestExpense"] * (1 - C.get("EffectiveTaxRateAsReported", 0.30)), C["TotalRevenue"]),
#     387     "NOPAT_to_Avg_InvestedCapital":    lambda C: safe_div(C["NetIncome"] + C["InterestExpense"] * (1 - 0.30), (C["TotalDebt"] + C["TotalEquity"] - C["Cash"]).rolling(2).mean()),
#     388     "ROIC":                            lambda C: safe_div(C["EarningBeforeInterestAndTax"], C["TotalDebt"] + C["TotalEquity"] - C["Cash"]),
#     389
#     390     # ─────────────────────────────────────── SOCIAL · RECOVER
#     391     "Equity_Issuance_Rate":            lambda C: safe_div(C["IssuanceOfCapitalStock"], C["TotalEquity"]),
#     392     "Share_Issuance_Rate":             lambda C: safe_div(C["BasicAverageShares"].diff(), C["BasicAverageShares"].shift(1)),
#     393     "Share_Dilution_3yrChg":           lambda C: safe_div(C["BasicAverageShares"], C.groupby(C["Symbol"])["BasicAverageShares"].shift(3)) - 1,
#     394
#     395     #### ADAPT STAGES
#     396
#     397      # ───────────────────────────────────── PHYSICAL · ADAPT
#     398     "CapEx_to_Sales":                  lambda C: safe_div(C["CapitalExpenditure"], C["TotalRevenue"]),
#     399     "CapEx_to_Depreciation":           lambda C: safe_div(C["CapitalExpenditure"], C["Depreciation"]),
#     400     "CapEx_plus_RnD_to_Sales":         lambda C: safe_div(C["CapitalExpenditure"] + C["ResearchAndDevelopment"], C["TotalRevenue"]),
#     401     "CapEx_GrowthRate":                lambda C: C.groupby(C["Symbol"])["CapitalExpenditure"].pct_change(),
#     402     "CapEx_Dep_Growth":                lambda C: safe_div(C["CapitalExpenditure"], C["Depreciation"]).pct_change(),
#     403     "Maintenance_CapEx_Ratio":         lambda C: safe_div(C["CapitalExpenditure"], C["Depreciation"]),
#     404     "FreeCashFlow_to_InvestedCapital": lambda C: safe_div(C["FreeCashFlow"], C["InvestedCapital"]),
#     405     "CapitalisedSoftware_to_Assets":   lambda C: safe_div(C.get("SoftwareIntangibles", 0), C["TotalAssets"]),
#     406     "Acquisitions_to_OCF":             lambda C: safe_div(C.get("AcquisitionsCashOutflow", 0), C["OperatingCashFlow"]),
#     407     "Reinvestment_Rate":               lambda C: safe_div(C["CapitalExpenditure"] - C["Depreciation"], C["OperatingCashFlow"]),
#     408     "CapEx_Variability_5yr":           lambda C: C.groupby(C["Symbol"])["CapitalExpenditure"].transform(lambda x: safe_div(x.rolling(5, 2).std(), x.rolling(5, 2).mean())),
#     409     "CapEx_Variability_3yr":           lambda C: C.groupby(C["Symbol"])["CapitalExpenditure"].transform(lambda x: safe_div(x.rolling(3, 2).std(), x.rolling(3, 2).mean())),
#     410     "OCF_to_CapEx":                    lambda C: safe_div(C["OperatingCashFlow"], C["CapitalExpenditure"]),
#     411     "OCF_FreeCash_Cushion":            lambda C: safe_div(C["OperatingCashFlow"] - C["CapitalExpenditure"] - C["CashDividendsPaid"], C["TotalRevenue"]),
#     412
#     413     # ─────────────────────────────────── INFORMATION · ADAPT
#     414     "Retention_Ratio":                 lambda C: 1 - safe_div(C["CashDividendsPaid"], C["NetIncome"]),
#     415     "Gross_Profitability":             lambda C: safe_div(C["GrossProfit"], C["TotalAssets"]),
#     416     "NOPAT_Margin":                    lambda C: safe_div(C["NetIncome"] + C["InterestExpense"] * (1 - 0.30), C["TotalRevenue"]),
#     417     "Sustainable_Growth_Rate":         lambda C: safe_div(C["NetIncome"], C["TotalEquity"]) * (1 - safe_div(C["CashDividendsPaid"], C["NetIncome"])),
#     418     "Revenue_CAGR_5yr":                lambda C: (safe_div(C["TotalRevenue"], C.groupby(C["Symbol"])["TotalRevenue"].shift(5)))**0.2 - 1,
#     419     "Revenue_CAGR_3yr":                lambda C: (safe_div(C["TotalRevenue"], C.groupby(C["Symbol"])["TotalRevenue"].shift(3)))**(1/3) - 1,
#     420     "Revenue_Growth":                  lambda C: C.groupby(C["Symbol"])["TotalRevenue"].pct_change(),
#     421     "NetIncome_Growth":                lambda C: C.groupby(C["Symbol"])["NetIncome"].pct_change(),
#     422     "EBITDA_Growth":                   lambda C: C.groupby(C["Symbol"])["EBITDA"].pct_change(),
#     423     "Assets_Growth":                   lambda C: C.groupby(C["Symbol"])["TotalAssets"].pct_change(),
#     424     "Equity_Growth":                   lambda C: C.groupby(C["Symbol"])["TotalEquity"].pct_change(),
#     425     "OCF_Growth":                      lambda C: C.groupby(C["Symbol"])["OperatingCashFlow"].pct_change(),
#     426     "FCF_Growth":                      lambda C: safe_div(C["FreeCashFlow"].diff(), C["FreeCashFlow"].shift(1)),
#     427     "FCF_Growth_3yrCAGR":              lambda C: (safe_div(C["FreeCashFlow"], C.groupby(C["Symbol"])["FreeCashFlow"].shift(3)))**(1/3) - 1,
#     428     "OCF_CAGR_5yr":                    lambda C: safe_div(C["OperatingCashFlow"], C.groupby(C["Symbol"])["OperatingCashFlow"].shift(5))**0.2 - 1,
#     429     "OCF_CAGR_3yr":                    lambda C: safe_div(C["OperatingCashFlow"], C.groupby(C["Symbol"])["OperatingCashFlow"].shift(3))**(1/3) - 1,
#     430     "Dividend_Growth":                 lambda C: C.groupby(C["Symbol"])["DividendPerShare"].pct_change(),
#     431     "Dividend_Growth_Alt":             lambda C: C.groupby(C["Symbol"])["CashDividendsPaid"].pct_change(),
#     432     "CapEx_Growth":                    lambda C: C.groupby(C["Symbol"])["CapitalExpenditure"].pct_change(),
#     433     "GrossProfit_Growth":              lambda C: C.groupby(C["Symbol"])["GrossProfit"].pct_change(),
#     434     "OCF_Volatility_3yr":              lambda C: C.groupby(C["Symbol"])["OperatingCashFlow"].transform(lambda x: safe_div(x.rolling(3,2).std(), x.rolling(3,2).mean())),
#     435     "CashFlow_Skewness":               lambda C: C.groupby(C["Symbol"])["OperatingCashFlow"].transform(lambda x: skew(x, 5)),
#     436     "FCF_Volatility_5yr":              lambda C: C.groupby(C["Symbol"])["FreeCashFlow"].transform(lambda x: safe_div(x.rolling(5,2).std(), x.rolling(5,2).mean())),
#     437     "OCF_Margin":                      lambda C: safe_div(C["OperatingCashFlow"], C["TotalRevenue"]),
#     438
#     439     # ───────────────────────────────────── COGNITIVE · ADAPT
#     440     "Market_Share_Ratio":              lambda C: safe_div(C["TotalRevenue"], C.groupby(C["SectorName"])["TotalRevenue"].transform("sum")),
#     441     "Relative_Revenue_Growth_vs_Sector": lambda C: C.groupby(C["SectorName"])["TotalRevenue"].pct_change() - C.groupby(C["Symbol"])["TotalRevenue"].pct_change(),
#     442     "Market_Share_Revenue_Change":     lambda C: safe_div(C["TotalRevenue"], C.groupby(C["SectorName"])["TotalRevenue"].transform("sum")),
#     443     "Market_Share_EBITDA_Change":      lambda C: safe_div(C["EBITDA"], C.groupby(C["SectorName"])["EBITDA"].transform("sum")),
#     444     "Relative_EBITDA_Growth_vs_Sector": lambda C: C.groupby(C["SectorName"])["EBITDA"].pct_change() - C.groupby(C["Symbol"])["EBITDA"].pct_change(),
#     445     "Relative_OperatingIncome_Growth_vs_Sector": lambda C: C.groupby(C["SectorName"])["OperatingIncome"].pct_change() - C.groupby(C["Symbol"])["OperatingIncome"].pct_change(),
#     446     "Market_Share_OperatingIncome_Change": lambda C: safe_div(C["OperatingIncome"], C.groupby(C["SectorName"])["OperatingIncome"].transform("sum")),
#     447     "Rev_CAGR_vs_Sector":              lambda C: C.groupby(C["SectorName"])["TotalRevenue"].transform(lambda x: x.pct_change(periods=3)),
#     448     "Relative_Revenue_Growth_Sector":  lambda C: C.groupby(C["SectorName"])["TotalRevenue"].pct_change(),
#     449     "Relative_EBITDA_Growth_Sector":   lambda C: C.groupby(C["SectorName"])["EBITDA"].pct_change(),
#     450     "Market_Share_of_Revenue":         lambda C: safe_div(C["TotalRevenue"], C.groupby(C["SectorName"])["TotalRevenue"].transform("sum")),
#     451     "Revenue_Sector_Share_Growth":     lambda C: ratio_funcs["Market_Share_of_Revenue"](C).groupby(C["Symbol"]).pct_change(),
#     452     "EBITDA_Sector_Share":             lambda C: safe_div(C["EBITDA"], C.groupby(C["SectorName"])["EBITDA"].transform("sum")),
#     453     "Relative_OperatingIncome_Growth_Sector": lambda C: C.groupby(C["SectorName"])["OperatingIncome"].pct_change(),
#     454     "Relative_NetIncome_Growth_Sector":       lambda C: C.groupby(C["SectorName"])["NetIncome"].pct_change(),
#     455     "NetIncome_Sector_Share":                 lambda C: safe_div(C["NetIncome"], C.groupby(C["SectorName"])["NetIncome"].transform("sum")),
#     456     "Sales_to_TotalAssets":            lambda C: safe_div(C["TotalRevenue"], C["TotalAssets"]),
#     457     "Sales_to_Marketing_Leverage":     lambda C: safe_div(C["TotalRevenue"].pct_change(), C["SellingAndMarketingExpense"].pct_change()),
#     458     "GrossMargin_Slope_5yr":           lambda C: C.groupby(C["Symbol"]).apply(lambda g: slope(g["GrossProfit"]/g["TotalRevenue"], 5)).reset_index(level=0, drop=True),
#     459     "GrossMargin_Slope_3yr":           lambda C: C.groupby(C["Symbol"]).apply(lambda g: slope(g["GrossProfit"]/g["TotalRevenue"], 3)).reset_index(level=0, drop=True),
#     460     "Price_Realisation_Index":         lambda C: (C["GrossProfit"]/C["TotalRevenue"]).diff() - safe_div(C["CostOfRevenue"].diff(), C["TotalRevenue"].shift(1)),
#     461
#     462     # ─────────────────────────────────────── SOCIAL · ADAPT
#     463     "DPS_to_EPS":                      lambda C: safe_div(C["DividendPerShare"], C.get("BasicEPS", pd.Series(np.nan))),
#     464     "Dividend_Payout_Ratio":           lambda C: safe_div(C["CashDividendsPaid"], C["NetIncome"]),
#     465     "FCF_Payout_Ratio":                lambda C: safe_div(C["CashDividendsPaid"], C["FreeCashFlow"]),
#     466     "Dividend_Stability_Index":        lambda C: C.groupby(C["Symbol"])["CashDividendsPaid"].transform(lambda x: x.notna().rolling(10, 1).sum() / 10),
#     467     "Dividend_Yield_on_FCF":           lambda C: safe_div(C["CashDividendsPaid"], C["FreeCashFlow"]),
#     468     "Dividend_Coverage":               lambda C: safe_div(C["OperatingCashFlow"], C["CashDividendsPaid"]),
#     469     "Dividend_Coverage_FCF":           lambda C: safe_div(C["OperatingCashFlow"] - C["CapitalExpenditure"], C["CashDividendsPaid"]),
#     470     "Dividend_Payout_CV":              lambda C: C.groupby(C["Symbol"]).apply(lambda g: safe_div((g["CashDividendsPaid"]/g["NetIncome"]).rolling(5,2).std(), (g["CashDividendsPaid"]/g["NetIncome"]).rolling(5,2).mean())).reset_index(level=0, drop=True),
#     471     "Share_Count_Reduction_YoY":       lambda C: -safe_div(C["BasicAverageShares"].diff(), C["BasicAverageShares"].shift(1)),
#     472     "Share_Dilution_3yrChg":           lambda C: safe_div(C["BasicAverageShares"], C.groupby(C["Symbol"])["BasicAverageShares"].shift(3)) - 1,
#     473     "Net_Buyback_to_FCF":              lambda C: safe_div(C.get("CommonStockRepurchased", 0) - C.get("IssuanceOfCapitalStock", 0), C["FreeCashFlow"]),
#     474 }
#     476 derived_ratio_funcs = {
#     477     # ── ratios that need ROIC ──
#     478     "ROIC_Slope_5yr"        : ratio_funcs.pop("ROIC_Slope_5yr"),
#    (...)
#     493     "Revenue_Sector_Share_Growth" : ratio_funcs.pop("Revenue_Sector_Share_Growth"),
#     494 }
#     496 # ------------------------------------------------------------------------------
#     497 # 1 ░░  DOMAIN-STAGE MAP  ░░  (165 keys)
#     498 # ------------------------------------------------------------------------------
#
# Cell In[1], line 115, in safe_div(a, b)
#     113     out = a / b
#     114 if isinstance(out, pd.Series):
# --> 115     return out.replace([np.inf, -np.inf], np.nan)
#     116 return np.where(np.isfinite(out), out, np.nan)
#
# File c:\Users\Jason Pohl\miniconda3\lib\site-packages\pandas\core\series.py:5223, in Series.replace(self, to_replace, value, inplace, limit, regex, method)
#    5207 @doc(
#    5208     NDFrame.replace,
#    5209     klass=_shared_doc_kwargs["klass"],
#    (...)
#    5221     method: Literal["pad", "ffill", "bfill"] | lib.NoDefault = lib.no_default,
#    5222 ) -> Series | None:
# -> 5223     return super().replace(
#    5224         to_replace=to_replace,
#    5225         value=value,
#    5226         inplace=inplace,
#    5227         limit=limit,
#    5228         regex=regex,
#    5229         method=method,
#    5230     )
#
# File c:\Users\Jason Pohl\miniconda3\lib\site-packages\pandas\core\generic.py:7347, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    7342     if len(to_replace) != len(value):
#    7343         raise ValueError(
#    7344             f"Replacement lists must match in length. "
#    7345             f"Expecting {len(to_replace)} got {len(value)} "
#    7346         )
# -> 7347     new_data = self._mgr.replace_list(
#    7348         src_list=to_replace,
#    7349         dest_list=value,
#    7350         inplace=inplace,
#    7351         regex=regex,
#    7352     )
#    7354 elif to_replace is None:
#    7355     if not (
#    7356         is_re_compilable(regex)
#    7357         or is_list_like(regex)
#    7358         or is_dict_like(regex)
#    7359     ):
#
# File c:\Users\Jason Pohl\miniconda3\lib\site-packages\pandas\core\internals\managers.py:496, in BaseBlockManager.replace_list(self, src_list, dest_list, inplace, regex)
#     493 """do a list replace"""
#     494 inplace = validate_bool_kwarg(inplace, "inplace")
# --> 496 bm = self.apply(
#     497     "replace_list",
#     498     src_list=src_list,
#     499     dest_list=dest_list,
#     500     inplace=inplace,
#     501     regex=regex,
#     502     using_cow=using_copy_on_write(),
#     503 )
#     504 bm._consolidate_inplace()
#     505 return bm
#
# File c:\Users\Jason Pohl\miniconda3\lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353     result_blocks = extend_blocks(applied, result_blocks)
#     355 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\Jason Pohl\miniconda3\lib\site-packages\pandas\core\internals\blocks.py:770, in Block.replace_list(self, src_list, dest_list, inplace, regex, using_cow)
#     767 else:
#     768     rb = [self if inplace else self.copy()]
# --> 770 for i, ((src, dest), mask) in enumerate(zip(pairs, masks)):
#     771     convert = i == src_len  # only convert once at the end
#     772     new_rb: list[Block] = []
#
# File c:\Users\Jason Pohl\miniconda3\lib\site-packages\pandas\core\internals\blocks.py:757, in <genexpr>(.0)
#     744     masks: Iterable[npt.NDArray[np.bool_]] = (
#     745         extract_bool_array(
#     746             cast(
#    (...)
#     753         for s in pairs
#     754     )
#     755 else:
#     756     # GH#38086 faster if we know we dont need to check for regex
# --> 757     masks = (missing.mask_missing(values, s[0]) for s in pairs)
#     758 # Materialize if inplace = True, since the masks can change
#     759 # as we replace
#     760 if inplace:
#
# File c:\Users\Jason Pohl\miniconda3\lib\site-packages\pandas\core\missing.py:108, in mask_missing(arr, values_to_mask)
#     106     new_mask[arr_mask] = arr[arr_mask] == x
#     107 else:
# --> 108     new_mask = arr == x
#     110     if not isinstance(new_mask, np.ndarray):
#     111         # usually BooleanArray
#     112         new_mask = new_mask.to_numpy(dtype=bool, na_value=False)
#
# KeyboardInterrupt:
