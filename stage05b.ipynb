# %%
#!/usr/bin/env python
"""
Stage 05B · Snapshot Logit Regressions
=====================================

Replaces the legacy “Stage 5C” and “Stage 5D”.

Given the quintile / score table produced by Stage 05A, run two **pre-Swan
(FY-SWAN-1)** logit models for every resilience metric:

A. Domain scores   (Physical / Information / Cognitive / Social)  
B. Stage  scores   (Prepare / Absorb / Recover / Adapt)

Inputs  (auto-discovered if RUN_DIR / RUN_DATE not provided)
-----------------------------------------------------------
<run>/stage05a/Stage5A_QuintilesAndScores.csv

Outputs
-------
<run>/stage05b/
   ├─ Stage5C_<Metric>_Coefficients.csv      (domain scores)
   ├─ Stage5D_<Metric>_StageCoefficients.csv (stage  scores)
   └─ stage05b.log
"""

from __future__ import annotations
from pathlib import Path
import os, sys, logging, yaml, warnings
from typing import Dict, List

import numpy as np
import pandas as pd
import statsmodels.api as sm

# ╔══════════════════════════════════════════════════════════════════╗
# 0 · PIPELINE CONFIG & PATH DISCOVERY                               #
# ╚══════════════════════════════════════════════════════════════════╝
CFG_FILE = Path(os.getenv("PIPELINE_CFG", "pipeline_config.yaml")).expanduser()
if not CFG_FILE.is_file():
    raise FileNotFoundError(f"pipeline_config.yaml not found at {CFG_FILE}")

CFG: Dict = yaml.safe_load(CFG_FILE.read_text()) or {}
DEFAULTS  = CFG.get("defaults", {})
EVENTS    = {str(k): v for k, v in CFG.get("events", {}).items()}

SWAN_YEAR = int(os.getenv("SWAN_YEAR", next(iter(EVENTS))))
if str(SWAN_YEAR) not in EVENTS:
    raise KeyError(f"SWAN_YEAR={SWAN_YEAR} not present in pipeline_config events:")

OUTPUT_ROOT = Path(DEFAULTS["OUTPUT_ROOT"]).expanduser()
EVENT_DIR   = OUTPUT_ROOT / f"event={SWAN_YEAR}"

# explicit override
RUN_DIR: Path | None = None
if os.getenv("RUN_DIR"):
    RUN_DIR = Path(os.getenv("RUN_DIR")).expanduser()
elif os.getenv("RUN_DATE"):
    RUN_DIR = EVENT_DIR / os.getenv("RUN_DATE")

# auto-detect latest Stage05A output if still None
if RUN_DIR is None:
    if not EVENT_DIR.is_dir():
        raise FileNotFoundError(f"No outputs for event={SWAN_YEAR} in {EVENT_DIR}")
    cand = list(EVENT_DIR.glob("*/stage05a/Stage5A_QuintilesAndScores.csv"))
    if not cand:
        raise FileNotFoundError(
            f"Stage5A_QuintilesAndScores.csv not found anywhere under {EVENT_DIR}. "
            "Run Stage 05A first."
        )
    QS_FILE = max(cand, key=lambda p: p.stat().st_mtime)
    RUN_DIR = QS_FILE.parents[1]          # …/<run_tag>/
else:
    QS_FILE = RUN_DIR / "stage05a" / "Stage5A_QuintilesAndScores.csv"
    if not QS_FILE.is_file():
        raise FileNotFoundError(f"{QS_FILE} not found – run Stage 05A first")

RUN_DATE    = RUN_DIR.name
STAGE5B_DIR = RUN_DIR / "stage05b"
STAGE5B_DIR.mkdir(parents=True, exist_ok=True)

# ╔══════════════════════════════════════════════════════════════════╗
# 1 · LOGGER                                                         #
# ╚══════════════════════════════════════════════════════════════════╝
logging.basicConfig(
    level   = logging.INFO,
    format  = "%(asctime)s | %(levelname)-7s | %(message)s",
    handlers=[
        logging.FileHandler(STAGE5B_DIR / "stage05b.log", mode="w", encoding="utf-8"),
        logging.StreamHandler(sys.stdout),
    ],
)
logger = logging.getLogger(__name__)
logger.info("==========  STAGE 05B: SNAPSHOT LOGIT REGRESSIONS ==========")
logger.info("SWAN_YEAR=%s  RUN_DATE=%s  RUN_DIR=%s", SWAN_YEAR, RUN_DATE, RUN_DIR)
warnings.filterwarnings("ignore", category=RuntimeWarning)

# ╔══════════════════════════════════════════════════════════════════╗
# 2 · LOAD QUINTILES & SCORES                                        #
# ╚══════════════════════════════════════════════════════════════════╝
df = pd.read_csv(QS_FILE)
logger.info("Loaded Stage05A table: %d rows × %d cols", *df.shape)

if "Year" not in df.columns:
    raise KeyError("'Year' column missing – Stage 05A should write it.")

PRE_YEAR = SWAN_YEAR - 1
snap = df[df["Year"] == PRE_YEAR].copy()
if snap.empty:
    raise ValueError(f"No FY-{PRE_YEAR} rows – check SWAN_YEAR & Stage 05A output.")
logger.info("Snapshot sample (FY-%d): %d rows", PRE_YEAR, len(snap))

# ╔══════════════════════════════════════════════════════════════════╗
# 3 · MODEL HELPERS                                                  #
# ╚══════════════════════════════════════════════════════════════════╝
METRICS = ["NetIncome","EarningBeforeInterestAndTax","OperatingIncome","EBITDA",
           "OperatingCashFlow","FreeCashFlow","Cash","CashAndCashEquivalents",
           "TotalRevenue","GrossProfit"]

DOMAINS = ["Physical_Score","Information_Score","Cognitive_Score","Social_Score"]
STAGES  = ["Prepare_Score","Absorb_Score","Recover_Score","Adapt_Score"]

def _fit_and_save(metric: str, predictors: List[str], tag: str) -> None:
    flag = f"Flag_{metric}"
    if flag not in snap.columns:
        logger.warning("%s: %s missing – skipped", metric, flag)
        return
    sub = snap[[flag] + predictors].dropna()
    if len(sub) < 50 or sub[flag].nunique() < 2:
        logger.warning("%s: insufficient data – skipped", metric)
        return

    y = sub[flag].astype(int)
    X = sm.add_constant(sub[predictors])
    try:
        mdl = sm.Logit(y, X).fit(disp=False)
    except Exception as e:
        logger.error("Fit error %s (%s): %s", metric, tag, e)
        return

    # notebook-friendly summary
    print(f"\n===== LOGIT ({tag}) – {metric}  (FY-{PRE_YEAR}) =====\n")
    print(mdl.summary())

    coef = (mdl.summary2().tables[1]
              .rename_axis("Term").reset_index()
              .rename(columns={"Coef.":"Coefficient",
                               "Std.Err.":"StdErr",
                               "P>|z|":"PValue"}))
    coef["OddsRatio"] = np.exp(coef["Coefficient"])
    coef = coef[["Term","Coefficient","StdErr","z","PValue",
                 "[0.025","0.975]","OddsRatio"]]
    out_csv = STAGE5B_DIR / f"{tag}_{metric}_Coefficients.csv"
    coef.to_csv(out_csv, index=False)
    print(f"→ saved {out_csv.name}")

# ╔══════════════════════════════════════════════════════════════════╗
# 4 · DOMAIN-SCORE MODELS (legacy 5C)                                #
# ╚══════════════════════════════════════════════════════════════════╝
missing_dom = [d for d in DOMAINS if d not in snap.columns]
if missing_dom:
    raise RuntimeError(f"Domain score columns missing: {missing_dom}")

logger.info("Running domain-score logits …")
for m in METRICS:
    _fit_and_save(m, DOMAINS, "Stage5C")

# ╔══════════════════════════════════════════════════════════════════╗
# 5 · STAGE-SCORE MODELS (legacy 5D)                                 #
# ╚══════════════════════════════════════════════════════════════════╝
missing_stg = [s for s in STAGES if s not in snap.columns]
if missing_stg:
    raise RuntimeError(f"Stage score columns missing: {missing_stg}")

logger.info("Running stage-score logits …")
for m in METRICS:
    _fit_and_save(m, STAGES, "Stage5D")

logger.info("✅  STAGE 05B complete – outputs in %s", STAGE5B_DIR)
print(f"\n✅ Stage 05B complete – coefficient CSVs saved to {STAGE5B_DIR}\n")
# Out:
# 2025-06-10 13:09:22,527 | INFO    | ==========  STAGE 05B: SNAPSHOT LOGIT REGRESSIONS ==========
# 2025-06-10 13:09:22,528 | INFO    | SWAN_YEAR=2008  RUN_DATE=20250609  RUN_DIR=C:\Users\Jason Pohl\OneDrive - Bond University\PhD\rff\outputs_rff\event=2008\20250609
# 2025-06-10 13:09:24,796 | INFO    | Loaded Stage05A table: 34862 rows × 686 cols
# 2025-06-10 13:09:24,809 | INFO    | Snapshot sample (FY-2007): 974 rows
# 2025-06-10 13:09:24,812 | INFO    | Running domain-score logits …
#
# ===== LOGIT (Stage5C) – NetIncome  (FY-2007) =====
#
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         Flag_NetIncome   No. Observations:                  903
# Model:                          Logit   Df Residuals:                      898
# Method:                           MLE   Df Model:                            4
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                 0.04488
# Time:                        13:09:24   Log-Likelihood:                -522.83
# converged:                       True   LL-Null:                       -547.40
# Covariance Type:            nonrobust   LLR p-value:                 5.471e-10
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -1.6144      0.498     -3.244      0.001      -2.590      -0.639
# Physical_Score       -0.1516      0.135     -1.119      0.263      -0.417       0.114
# Information_Score     0.1743      0.134      1.302      0.193      -0.088       0.437
# Cognitive_Score       0.4344      0.109      3.992      0.000       0.221       0.648
# Social_Score          0.4650      0.105      4.423      0.000       0.259       0.671
# =====================================================================================
# → saved Stage5C_NetIncome_Coefficients.csv
#
# ===== LOGIT (Stage5C) – EarningBeforeInterestAndTax  (FY-2007) =====
#
#                                   Logit Regression Results
# ============================================================================================
# Dep. Variable:     Flag_EarningBeforeInterestAndTax   No. Observations:                  903
# Model:                                        Logit   Df Residuals:                      898
# Method:                                         MLE   Df Model:                            4
# Date:                              Tue, 10 Jun 2025   Pseudo R-squ.:                 0.04752
# Time:                                      13:09:24   Log-Likelihood:                -497.04
# converged:                                     True   LL-Null:                       -521.83
# Covariance Type:                          nonrobust   LLR p-value:                 4.395e-10
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 0.4066      0.524      0.775      0.438      -0.621       1.434
# Physical_Score       -0.1222      0.139     -0.880      0.379      -0.394       0.150
# Information_Score    -0.4904      0.138     -3.561      0.000      -0.760      -0.220
# Cognitive_Score       0.5946      0.113      5.274      0.000       0.374       0.816
# Social_Score          0.1753      0.109      1.602      0.109      -0.039       0.390
# =====================================================================================
# → saved Stage5C_EarningBeforeInterestAndTax_Coefficients.csv
#
# ===== LOGIT (Stage5C) – OperatingIncome  (FY-2007) =====
#
#                             Logit Regression Results
# ================================================================================
# Dep. Variable:     Flag_OperatingIncome   No. Observations:                  903
# Model:                            Logit   Df Residuals:                      898
# Method:                             MLE   Df Model:                            4
# Date:                  Tue, 10 Jun 2025   Pseudo R-squ.:                 0.06493
# Time:                          13:09:24   Log-Likelihood:                -473.01
# converged:                         True   LL-Null:                       -505.86
# Covariance Type:              nonrobust   LLR p-value:                 1.843e-13
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 0.4792      0.541      0.885      0.376      -0.582       1.540
# Physical_Score        0.0672      0.141      0.476      0.634      -0.210       0.344
# Information_Score    -0.6017      0.142     -4.244      0.000      -0.880      -0.324
# Cognitive_Score       0.6142      0.115      5.321      0.000       0.388       0.840
# Social_Score          0.1105      0.113      0.976      0.329      -0.111       0.333
# =====================================================================================
# → saved Stage5C_OperatingIncome_Coefficients.csv
#
# ===== LOGIT (Stage5C) – EBITDA  (FY-2007) =====
#
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:            Flag_EBITDA   No. Observations:                  903
# Model:                          Logit   Df Residuals:                      898
# Method:                           MLE   Df Model:                            4
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                 0.06066
# Time:                        13:09:24   Log-Likelihood:                -467.74
# converged:                       True   LL-Null:                       -497.95
# Covariance Type:            nonrobust   LLR p-value:                 2.383e-12
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 0.3949      0.543      0.727      0.467      -0.669       1.459
# Physical_Score       -0.1219      0.142     -0.856      0.392      -0.401       0.157
# Information_Score    -0.5278      0.142     -3.725      0.000      -0.806      -0.250
# Cognitive_Score       0.6849      0.116      5.905      0.000       0.458       0.912
# Social_Score          0.1813      0.114      1.595      0.111      -0.042       0.404
# =====================================================================================
# → saved Stage5C_EBITDA_Coefficients.csv
#
# ===== LOGIT (Stage5C) – OperatingCashFlow  (FY-2007) =====
#
#                              Logit Regression Results
# ==================================================================================
# Dep. Variable:     Flag_OperatingCashFlow   No. Observations:                  903
# Model:                              Logit   Df Residuals:                      898
# Method:                               MLE   Df Model:                            4
# Date:                    Tue, 10 Jun 2025   Pseudo R-squ.:                  0.2727
# Time:                            13:09:24   Log-Likelihood:                -222.48
# converged:                           True   LL-Null:                       -305.88
# Covariance Type:                nonrobust   LLR p-value:                 5.081e-35
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                11.4356      1.577      7.250      0.000       8.344      14.527
# Physical_Score       -0.5956      0.402     -1.483      0.138      -1.383       0.192
# Information_Score     1.0449      0.335      3.115      0.002       0.388       1.702
# Cognitive_Score      -2.3025      0.438     -5.260      0.000      -3.160      -1.444
# Social_Score         -0.9059      0.217     -4.174      0.000      -1.331      -0.481
# =====================================================================================
# → saved Stage5C_OperatingCashFlow_Coefficients.csv
#
# ===== LOGIT (Stage5C) – FreeCashFlow  (FY-2007) =====
#
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:      Flag_FreeCashFlow   No. Observations:                  903
# Model:                          Logit   Df Residuals:                      898
# Method:                           MLE   Df Model:                            4
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                 0.02099
# Time:                        13:09:24   Log-Likelihood:                -555.68
# converged:                       True   LL-Null:                       -567.59
# Covariance Type:            nonrobust   LLR p-value:                 8.651e-05
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 2.0315      0.513      3.963      0.000       1.027       3.036
# Physical_Score       -0.6614      0.140     -4.730      0.000      -0.935      -0.387
# Information_Score    -0.1156      0.133     -0.868      0.385      -0.377       0.146
# Cognitive_Score       0.3317      0.108      3.057      0.002       0.119       0.544
# Social_Score         -0.1191      0.104     -1.145      0.252      -0.323       0.085
# =====================================================================================
# → saved Stage5C_FreeCashFlow_Coefficients.csv
#
# ===== LOGIT (Stage5C) – Cash  (FY-2007) =====
#
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Flag_Cash   No. Observations:                  903
# Model:                          Logit   Df Residuals:                      898
# Method:                           MLE   Df Model:                            4
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                 0.02362
# Time:                        13:09:24   Log-Likelihood:                -529.25
# converged:                       True   LL-Null:                       -542.06
# Covariance Type:            nonrobust   LLR p-value:                 3.792e-05
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.8102      0.493     -1.643      0.100      -1.777       0.156
# Physical_Score        0.3535      0.137      2.579      0.010       0.085       0.622
# Information_Score     0.0576      0.132      0.436      0.663      -0.202       0.317
# Cognitive_Score       0.1423      0.110      1.289      0.198      -0.074       0.359
# Social_Score          0.1475      0.105      1.410      0.158      -0.058       0.353
# =====================================================================================
# → saved Stage5C_Cash_Coefficients.csv
#
# ===== LOGIT (Stage5C) – CashAndCashEquivalents  (FY-2007) =====
#
#                                 Logit Regression Results
# =======================================================================================
# Dep. Variable:     Flag_CashAndCashEquivalents   No. Observations:                  903
# Model:                                   Logit   Df Residuals:                      898
# Method:                                    MLE   Df Model:                            4
# Date:                         Tue, 10 Jun 2025   Pseudo R-squ.:                 0.06748
# Time:                                 13:09:24   Log-Likelihood:                -525.04
# converged:                                True   LL-Null:                       -563.04
# Covariance Type:                     nonrobust   LLR p-value:                 1.232e-15
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -2.1527      0.496     -4.339      0.000      -3.125      -1.180
# Physical_Score        0.4199      0.134      3.141      0.002       0.158       0.682
# Information_Score     0.0201      0.130      0.155      0.877      -0.235       0.275
# Cognitive_Score       0.3854      0.108      3.575      0.000       0.174       0.597
# Social_Score          0.3365      0.105      3.204      0.001       0.131       0.542
# =====================================================================================
# → saved Stage5C_CashAndCashEquivalents_Coefficients.csv
#
# ===== LOGIT (Stage5C) – TotalRevenue  (FY-2007) =====
#
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:      Flag_TotalRevenue   No. Observations:                  903
# Model:                          Logit   Df Residuals:                      898
# Method:                           MLE   Df Model:                            4
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                 0.04264
# Time:                        13:09:24   Log-Likelihood:                -435.76
# converged:                       True   LL-Null:                       -455.17
# Covariance Type:            nonrobust   LLR p-value:                 7.596e-08
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -1.1512      0.541     -2.126      0.033      -2.212      -0.090
# Physical_Score        0.6788      0.159      4.271      0.000       0.367       0.990
# Information_Score    -0.0089      0.149     -0.060      0.952      -0.301       0.283
# Cognitive_Score      -0.2316      0.133     -1.736      0.083      -0.493       0.030
# Social_Score          0.5648      0.117      4.815      0.000       0.335       0.795
# =====================================================================================
# → saved Stage5C_TotalRevenue_Coefficients.csv
#
# ===== LOGIT (Stage5C) – GrossProfit  (FY-2007) =====
#
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       Flag_GrossProfit   No. Observations:                  903
# Model:                          Logit   Df Residuals:                      898
# Method:                           MLE   Df Model:                            4
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                 0.08547
# Time:                        13:09:24   Log-Likelihood:                -378.63
# converged:                       True   LL-Null:                       -414.02
# Covariance Type:            nonrobust   LLR p-value:                 1.556e-14
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 1.9153      0.641      2.988      0.003       0.659       3.172
# Physical_Score        0.6235      0.173      3.601      0.000       0.284       0.963
# Information_Score    -1.0801      0.170     -6.351      0.000      -1.413      -0.747
# Cognitive_Score      -0.1312      0.150     -0.873      0.382      -0.426       0.163
# Social_Score          0.3964      0.130      3.046      0.002       0.141       0.651
# =====================================================================================
# → saved Stage5C_GrossProfit_Coefficients.csv
# 2025-06-10 13:09:24,986 | INFO    | Running stage-score logits …
#
# ===== LOGIT (Stage5D) – NetIncome  (FY-2007) =====
#
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:         Flag_NetIncome   No. Observations:                  973
# Model:                          Logit   Df Residuals:                      968
# Method:                           MLE   Df Model:                            4
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                  0.1177
# Time:                        13:09:24   Log-Likelihood:                -541.22
# converged:                       True   LL-Null:                       -613.39
# Covariance Type:            nonrobust   LLR p-value:                 3.331e-30
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.5840      0.452     -1.293      0.196      -1.469       0.301
# Prepare_Score     0.5603      0.167      3.351      0.001       0.233       0.888
# Absorb_Score      0.5808      0.179      3.243      0.001       0.230       0.932
# Recover_Score    -0.8559      0.141     -6.081      0.000      -1.132      -0.580
# Adapt_Score       0.5275      0.147      3.578      0.000       0.239       0.817
# =================================================================================
# → saved Stage5D_NetIncome_Coefficients.csv
#
# ===== LOGIT (Stage5D) – EarningBeforeInterestAndTax  (FY-2007) =====
#
#                                   Logit Regression Results
# ============================================================================================
# Dep. Variable:     Flag_EarningBeforeInterestAndTax   No. Observations:                  973
# Model:                                        Logit   Df Residuals:                      968
# Method:                                         MLE   Df Model:                            4
# Date:                              Tue, 10 Jun 2025   Pseudo R-squ.:                 0.06770
# Time:                                      13:09:25   Log-Likelihood:                -551.82
# converged:                                     True   LL-Null:                       -591.89
# Covariance Type:                          nonrobust   LLR p-value:                 1.622e-16
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.5849      0.445     -1.315      0.189      -1.457       0.287
# Prepare_Score     0.2931      0.164      1.785      0.074      -0.029       0.615
# Absorb_Score      0.2558      0.174      1.468      0.142      -0.086       0.597
# Recover_Score    -0.5990      0.136     -4.411      0.000      -0.865      -0.333
# Adapt_Score       0.6991      0.146      4.777      0.000       0.412       0.986
# =================================================================================
# → saved Stage5D_EarningBeforeInterestAndTax_Coefficients.csv
#
# ===== LOGIT (Stage5D) – OperatingIncome  (FY-2007) =====
#
#                             Logit Regression Results
# ================================================================================
# Dep. Variable:     Flag_OperatingIncome   No. Observations:                  973
# Model:                            Logit   Df Residuals:                      968
# Method:                             MLE   Df Model:                            4
# Date:                  Tue, 10 Jun 2025   Pseudo R-squ.:                 0.05958
# Time:                          13:09:25   Log-Likelihood:                -543.95
# converged:                         True   LL-Null:                       -578.41
# Covariance Type:              nonrobust   LLR p-value:                 3.835e-14
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -1.1100      0.449     -2.474      0.013      -1.989      -0.231
# Prepare_Score     0.4167      0.165      2.520      0.012       0.093       0.741
# Absorb_Score      0.2908      0.177      1.644      0.100      -0.056       0.638
# Recover_Score    -0.3026      0.134     -2.251      0.024      -0.566      -0.039
# Adapt_Score       0.5130      0.146      3.508      0.000       0.226       0.800
# =================================================================================
# → saved Stage5D_OperatingIncome_Coefficients.csv
#
# ===== LOGIT (Stage5D) – EBITDA  (FY-2007) =====
#
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:            Flag_EBITDA   No. Observations:                  973
# Model:                          Logit   Df Residuals:                      968
# Method:                           MLE   Df Model:                            4
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                 0.08443
# Time:                        13:09:25   Log-Likelihood:                -523.46
# converged:                       True   LL-Null:                       -571.73
# Covariance Type:            nonrobust   LLR p-value:                 5.362e-20
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.6609      0.459     -1.440      0.150      -1.560       0.239
# Prepare_Score     0.2660      0.168      1.585      0.113      -0.063       0.595
# Absorb_Score      0.3624      0.180      2.012      0.044       0.009       0.715
# Recover_Score    -0.6621      0.140     -4.723      0.000      -0.937      -0.387
# Adapt_Score       0.7851      0.152      5.170      0.000       0.487       1.083
# =================================================================================
# → saved Stage5D_EBITDA_Coefficients.csv
#
# ===== LOGIT (Stage5D) – OperatingCashFlow  (FY-2007) =====
#
#                              Logit Regression Results
# ==================================================================================
# Dep. Variable:     Flag_OperatingCashFlow   No. Observations:                  973
# Model:                              Logit   Df Residuals:                      968
# Method:                               MLE   Df Model:                            4
# Date:                    Tue, 10 Jun 2025   Pseudo R-squ.:                  0.1913
# Time:                            13:09:25   Log-Likelihood:                -257.04
# converged:                           True   LL-Null:                       -317.84
# Covariance Type:                nonrobust   LLR p-value:                 2.437e-25
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            12.2066      1.287      9.483      0.000       9.684      14.730
# Prepare_Score    -1.1569      0.387     -2.992      0.003      -1.915      -0.399
# Absorb_Score     -0.0372      0.351     -0.106      0.916      -0.726       0.652
# Recover_Score    -0.7963      0.262     -3.044      0.002      -1.309      -0.284
# Adapt_Score      -1.4372      0.298     -4.820      0.000      -2.022      -0.853
# =================================================================================
# → saved Stage5D_OperatingCashFlow_Coefficients.csv
#
# ===== LOGIT (Stage5D) – FreeCashFlow  (FY-2007) =====
#
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:      Flag_FreeCashFlow   No. Observations:                  973
# Model:                          Logit   Df Residuals:                      968
# Method:                           MLE   Df Model:                            4
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                 0.02625
# Time:                        13:09:25   Log-Likelihood:                -613.70
# converged:                       True   LL-Null:                       -630.24
# Covariance Type:            nonrobust   LLR p-value:                 1.144e-06
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             1.6631      0.435      3.826      0.000       0.811       2.515
# Prepare_Score     0.1686      0.161      1.047      0.295      -0.147       0.484
# Absorb_Score      0.3973      0.173      2.302      0.021       0.059       0.736
# Recover_Score    -0.5380      0.129     -4.158      0.000      -0.792      -0.284
# Adapt_Score      -0.1851      0.137     -1.353      0.176      -0.453       0.083
# =================================================================================
# → saved Stage5D_FreeCashFlow_Coefficients.csv
#
# ===== LOGIT (Stage5D) – Cash  (FY-2007) =====
#
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Flag_Cash   No. Observations:                  973
# Model:                          Logit   Df Residuals:                      968
# Method:                           MLE   Df Model:                            4
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                 0.03382
# Time:                        13:09:25   Log-Likelihood:                -579.96
# converged:                       True   LL-Null:                       -600.26
# Covariance Type:            nonrobust   LLR p-value:                 3.252e-08
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -1.5132      0.432     -3.507      0.000      -2.359      -0.667
# Prepare_Score     0.4991      0.162      3.074      0.002       0.181       0.817
# Absorb_Score     -0.1665      0.168     -0.990      0.322      -0.496       0.163
# Recover_Score     0.1235      0.129      0.958      0.338      -0.129       0.376
# Adapt_Score       0.4094      0.139      2.939      0.003       0.136       0.682
# =================================================================================
# → saved Stage5D_Cash_Coefficients.csv
#
# ===== LOGIT (Stage5D) – CashAndCashEquivalents  (FY-2007) =====
#
#                                 Logit Regression Results
# =======================================================================================
# Dep. Variable:     Flag_CashAndCashEquivalents   No. Observations:                  973
# Model:                                   Logit   Df Residuals:                      968
# Method:                                    MLE   Df Model:                            4
# Date:                         Tue, 10 Jun 2025   Pseudo R-squ.:                 0.07550
# Time:                                 13:09:25   Log-Likelihood:                -573.63
# converged:                                True   LL-Null:                       -620.48
# Covariance Type:                     nonrobust   LLR p-value:                 2.161e-19
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -2.2877      0.440     -5.205      0.000      -3.149      -1.426
# Prepare_Score     0.4469      0.161      2.773      0.006       0.131       0.763
# Absorb_Score      0.5772      0.174      3.319      0.001       0.236       0.918
# Recover_Score     0.0425      0.129      0.328      0.743      -0.211       0.296
# Adapt_Score       0.3044      0.140      2.172      0.030       0.030       0.579
# =================================================================================
# → saved Stage5D_CashAndCashEquivalents_Coefficients.csv
#
# ===== LOGIT (Stage5D) – TotalRevenue  (FY-2007) =====
#
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:      Flag_TotalRevenue   No. Observations:                  973
# Model:                          Logit   Df Residuals:                      968
# Method:                           MLE   Df Model:                            4
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                 0.03770
# Time:                        13:09:25   Log-Likelihood:                -454.04
# converged:                       True   LL-Null:                       -471.83
# Covariance Type:            nonrobust   LLR p-value:                 3.536e-07
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.7040      0.492     -1.432      0.152      -1.668       0.260
# Prepare_Score     0.0939      0.194      0.485      0.628      -0.286       0.474
# Absorb_Score     -0.4834      0.193     -2.507      0.012      -0.861      -0.105
# Recover_Score     0.6096      0.154      3.962      0.000       0.308       0.911
# Adapt_Score       0.3815      0.162      2.355      0.019       0.064       0.699
# =================================================================================
# → saved Stage5D_TotalRevenue_Coefficients.csv
#
# ===== LOGIT (Stage5D) – GrossProfit  (FY-2007) =====
#
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       Flag_GrossProfit   No. Observations:                  973
# Model:                          Logit   Df Residuals:                      968
# Method:                           MLE   Df Model:                            4
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                 0.06967
# Time:                        13:09:25   Log-Likelihood:                -400.02
# converged:                       True   LL-Null:                       -429.98
# Covariance Type:            nonrobust   LLR p-value:                 3.024e-12
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.7580      0.542      1.398      0.162      -0.305       1.821
# Prepare_Score    -0.6012      0.220     -2.734      0.006      -1.032      -0.170
# Absorb_Score     -0.7450      0.205     -3.637      0.000      -1.147      -0.343
# Recover_Score     0.6122      0.166      3.677      0.000       0.286       0.938
# Adapt_Score       0.6281      0.174      3.614      0.000       0.287       0.969
# =================================================================================
# → saved Stage5D_GrossProfit_Coefficients.csv
# 2025-06-10 13:09:25,179 | INFO    | ✅  STAGE 05B complete – outputs in C:\Users\Jason Pohl\OneDrive - Bond University\PhD\rff\outputs_rff\event=2008\20250609\stage05b
#
# ✅ Stage 05B complete – coefficient CSVs saved to C:\Users\Jason Pohl\OneDrive - Bond University\PhD\rff\outputs_rff\event=2008\20250609\stage05b
